# %%
import os
from pathlib import Path
import joblib

CACHE_DIR = Path("cache")
CACHE_DIR.mkdir(exist_ok=True)
VECTORS_PATH = CACHE_DIR / "dense_vectors.pkl"
FILENAMES_PATH = CACHE_DIR / "filenames.pkl"
VECTORIZER_PATH = CACHE_DIR / "vectorizer.pkl"
LSH_CACHE_PATH = CACHE_DIR / "lsh_index.pkl"

def save_to_cache(dense_vectors, filenames, vectorizer):
    joblib.dump(dense_vectors, VECTORS_PATH)
    joblib.dump(filenames, FILENAMES_PATH)
    joblib.dump(vectorizer, VECTORIZER_PATH)

def load_from_cache():
    dense_vectors = joblib.load(VECTORS_PATH)
    filenames = joblib.load(FILENAMES_PATH)
    vectorizer = joblib.load(VECTORIZER_PATH)
    return dense_vectors, filenames, vectorizer

def is_cache_available():
    return VECTORS_PATH.exists() and FILENAMES_PATH.exists() and VECTORIZER_PATH.exists()

# %%
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

def load_license_texts_parallel(data_dir, max_workers=16):
    data_dir = Path(data_dir)
    files = list(data_dir.rglob("*.txt"))
    
    texts = []
    filenames = []

    def read_file(file_path):
        try:
            text = file_path.read_text(encoding="utf-8")
            return str(file_path.relative_to(data_dir)), text
        except Exception as e:
            return None

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for result in tqdm(executor.map(read_file, files), total=len(files), desc="Reading files"):
            if result:
                rel_path, text = result
                filenames.append(rel_path)
                texts.append(text)

    return filenames, texts

# %%
import time
from pathlib import Path
from sentence_transformers import SentenceTransformer

project_root = Path("..").resolve()
output_base = project_root / "Combined-Licenses"

start_time = time.time()

if is_cache_available():
    print("[CACHE HIT] Loading Dense vectors...")
    dense_vectors, filenames, vectorizer = load_from_cache()
else:
    print("[CACHE MISS] Processing license texts...")
    t0 = time.time()
    filenames, texts = load_license_texts_parallel(output_base)
    sample_texts = texts[:10000]
    sample_filenames = filenames[:10000]
    
    model = SentenceTransformer("all-MiniLM-L6-v2")
    print(" Creating vectors on 10,000 samples only...")
    dense_vectors = model.encode(sample_texts, show_progress_bar=True)
    print("Vectors created for 10,000 samples.")
    save_to_cache(dense_vectors, sample_filenames, model)
    print(f"--- TF-IDF built in {time.time() - t0:.2f} sec")
# Out:
# [CACHE MISS] Processing license texts...
# Reading files: 100%|██████████████████| 162835/162835 [00:21<00:00, 7570.79it/s]
#  Creating vectors on 10,000 samples only...
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Vectors created for 10,000 samples.
# --- TF-IDF built in 291.19 sec

# %%
# dense_vectors.shape
# len(sample_filenames)
# len(filenames)
# Out:
# 162835

# %%
import sys
import time
import joblib
from tqdm import tqdm
from pathlib import Path

# Setup paths and import
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))
from LSH import LSH

start_time = time.time()

if LSH_CACHE_PATH.exists():
    print("[CACHE HIT] Loading existing LSH index...")
    lsh = joblib.load(LSH_CACHE_PATH)
else:
    print("[CACHE MISS] Building LSH index...")
    hash_size = 32
    input_dim = dense_vectors.shape[1]
    num_tables = 30
    lsh = LSH(hash_size, input_dim, num_tables)

    BATCH_SIZE = 500
    num_vectors = dense_vectors.shape[0]
    total_added = 0

    for start in tqdm(range(0, num_vectors, BATCH_SIZE), desc=" Adding vectors to LSH"):
        end = min(start + BATCH_SIZE, num_vectors)
        dense_batch = dense_vectors[start:end]
        for i, vector in enumerate(dense_batch):
            lsh.add(vector, sample_filenames[start + i])
            total_added += 1
            if total_added % 10000 == 0:
                print(f"[DEBUG] Added {total_added} vectors...")

    print("Saving LSH index to cache...")
    LSH_CACHE_PATH.parent.mkdir(parents=True, exist_ok=True)
    joblib.dump(lsh, LSH_CACHE_PATH)

print(f"Done! Total time: {time.time() - start_time:.2f} sec")
# Out:
# [CACHE MISS] Building LSH index...
# 🔗 Adding vectors to LSH:   0%|                          | 0/20 [00:00<?, ?it/s]
# [DEBUG] Collision in table 0, bucket 10010110... → 2 items
# [DEBUG] Collision in table 1, bucket 00100100... → 2 items
# [DEBUG] Collision in table 2, bucket 10100000... → 2 items
# [DEBUG] Collision in table 3, bucket 00000100... → 2 items
# [DEBUG] Collision in table 4, bucket 00110000... → 2 items
# [DEBUG] Collision in table 5, bucket 00011000... → 2 items
# [DEBUG] Collision in table 6, bucket 00001011... → 2 items
# [DEBUG] Collision in table 7, bucket 00000010... → 2 items
# [DEBUG] Collision in table 8, bucket 10000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100110... → 2 items
# [DEBUG] Collision in table 10, bucket 00010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 00001100... → 2 items
# [DEBUG] Collision in table 13, bucket 01000001... → 2 items
# [DEBUG] Collision in table 14, bucket 00000000... → 2 items
# [DEBUG] Collision in table 15, bucket 01010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00011010... → 2 items
# [DEBUG] Collision in table 20, bucket 00011000... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010000... → 2 items
# [DEBUG] Collision in table 23, bucket 00010000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 01000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00000100... → 2 items
# [DEBUG] Collision in table 27, bucket 00001110... → 2 items
# [DEBUG] Collision in table 28, bucket 11001000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10010110... → 3 items
# [DEBUG] Collision in table 1, bucket 00100100... → 3 items
# [DEBUG] Collision in table 2, bucket 10100000... → 3 items
# [DEBUG] Collision in table 3, bucket 00000100... → 3 items
# [DEBUG] Collision in table 4, bucket 00110000... → 3 items
# [DEBUG] Collision in table 5, bucket 00011000... → 3 items
# [DEBUG] Collision in table 6, bucket 00001011... → 3 items
# [DEBUG] Collision in table 7, bucket 00000010... → 3 items
# [DEBUG] Collision in table 8, bucket 10000000... → 3 items
# [DEBUG] Collision in table 9, bucket 10100110... → 3 items
# [DEBUG] Collision in table 10, bucket 00010000... → 3 items
# [DEBUG] Collision in table 11, bucket 00000001... → 3 items
# [DEBUG] Collision in table 12, bucket 00001100... → 3 items
# [DEBUG] Collision in table 13, bucket 01000001... → 3 items
# [DEBUG] Collision in table 14, bucket 00000000... → 3 items
# [DEBUG] Collision in table 15, bucket 01010000... → 3 items
# [DEBUG] Collision in table 16, bucket 00100000... → 3 items
# [DEBUG] Collision in table 17, bucket 00000000... → 3 items
# [DEBUG] Collision in table 18, bucket 00000010... → 3 items
# [DEBUG] Collision in table 19, bucket 00011010... → 3 items
# [DEBUG] Collision in table 20, bucket 00011000... → 3 items
# [DEBUG] Collision in table 21, bucket 00010000... → 3 items
# [DEBUG] Collision in table 22, bucket 10010000... → 3 items
# [DEBUG] Collision in table 23, bucket 00010000... → 3 items
# [DEBUG] Collision in table 24, bucket 00100000... → 3 items
# [DEBUG] Collision in table 25, bucket 01000110... → 3 items
# [DEBUG] Collision in table 26, bucket 00000100... → 3 items
# [DEBUG] Collision in table 27, bucket 00001110... → 3 items
# [DEBUG] Collision in table 28, bucket 11001000... → 3 items
# [DEBUG] Collision in table 29, bucket 00000110... → 3 items
# [DEBUG] Collision in table 0, bucket 10010110... → 4 items
# [DEBUG] Collision in table 1, bucket 00100100... → 4 items
# [DEBUG] Collision in table 2, bucket 10100000... → 4 items
# [DEBUG] Collision in table 3, bucket 00000100... → 4 items
# [DEBUG] Collision in table 4, bucket 00110000... → 4 items
# [DEBUG] Collision in table 5, bucket 00011000... → 4 items
# [DEBUG] Collision in table 6, bucket 00001011... → 4 items
# [DEBUG] Collision in table 7, bucket 00000010... → 4 items
# [DEBUG] Collision in table 8, bucket 10000000... → 4 items
# [DEBUG] Collision in table 9, bucket 10100110... → 4 items
# [DEBUG] Collision in table 10, bucket 00010000... → 4 items
# [DEBUG] Collision in table 11, bucket 00000001... → 4 items
# [DEBUG] Collision in table 12, bucket 00001100... → 4 items
# [DEBUG] Collision in table 13, bucket 01000001... → 4 items
# [DEBUG] Collision in table 14, bucket 00000000... → 4 items
# [DEBUG] Collision in table 15, bucket 01010000... → 4 items
# [DEBUG] Collision in table 16, bucket 00100000... → 4 items
# [DEBUG] Collision in table 17, bucket 00000000... → 4 items
# [DEBUG] Collision in table 18, bucket 00000010... → 4 items
# [DEBUG] Collision in table 19, bucket 00011010... → 4 items
# [DEBUG] Collision in table 20, bucket 00011000... → 4 items
# [DEBUG] Collision in table 21, bucket 00010000... → 4 items
# [DEBUG] Collision in table 22, bucket 10010000... → 4 items
# [DEBUG] Collision in table 23, bucket 00010000... → 4 items
# [DEBUG] Collision in table 24, bucket 00100000... → 4 items
# [DEBUG] Collision in table 25, bucket 01000110... → 4 items
# [DEBUG] Collision in table 26, bucket 00000100... → 4 items
# [DEBUG] Collision in table 27, bucket 00001110... → 4 items
# [DEBUG] Collision in table 28, bucket 11001000... → 4 items
# [DEBUG] Collision in table 29, bucket 00000110... → 4 items
# [DEBUG] Collision in table 0, bucket 10010110... → 5 items
# [DEBUG] Collision in table 1, bucket 00100100... → 5 items
# [DEBUG] Collision in table 2, bucket 10100000... → 5 items
# [DEBUG] Collision in table 3, bucket 00000100... → 5 items
# [DEBUG] Collision in table 4, bucket 00110000... → 5 items
# [DEBUG] Collision in table 5, bucket 00011000... → 5 items
# [DEBUG] Collision in table 6, bucket 00001011... → 5 items
# [DEBUG] Collision in table 7, bucket 00000010... → 5 items
# [DEBUG] Collision in table 8, bucket 10000000... → 5 items
# [DEBUG] Collision in table 9, bucket 10100110... → 5 items
# [DEBUG] Collision in table 10, bucket 00010000... → 5 items
# [DEBUG] Collision in table 11, bucket 00000001... → 5 items
# [DEBUG] Collision in table 12, bucket 00001100... → 5 items
# [DEBUG] Collision in table 13, bucket 01000001... → 5 items
# [DEBUG] Collision in table 14, bucket 00000000... → 5 items
# [DEBUG] Collision in table 15, bucket 01010000... → 5 items
# [DEBUG] Collision in table 16, bucket 00100000... → 5 items
# [DEBUG] Collision in table 17, bucket 00000000... → 5 items
# [DEBUG] Collision in table 18, bucket 00000010... → 5 items
# [DEBUG] Collision in table 19, bucket 00011010... → 5 items
# [DEBUG] Collision in table 20, bucket 00011000... → 5 items
# [DEBUG] Collision in table 21, bucket 00010000... → 5 items
# [DEBUG] Collision in table 22, bucket 10010000... → 5 items
# [DEBUG] Collision in table 23, bucket 00010000... → 5 items
# [DEBUG] Collision in table 24, bucket 00100000... → 5 items
# [DEBUG] Collision in table 25, bucket 01000110... → 5 items
# [DEBUG] Collision in table 26, bucket 00000100... → 5 items
# [DEBUG] Collision in table 27, bucket 00001110... → 5 items
# [DEBUG] Collision in table 28, bucket 11001000... → 5 items
# [DEBUG] Collision in table 29, bucket 00000110... → 5 items
# [DEBUG] Collision in table 8, bucket 11000000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 16, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 10000100... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 01000001... → 2 items
# [DEBUG] Collision in table 3, bucket 00111000... → 2 items
# [DEBUG] Collision in table 4, bucket 01100100... → 2 items
# [DEBUG] Collision in table 5, bucket 01001011... → 2 items
# [DEBUG] Collision in table 6, bucket 00101001... → 2 items
# [DEBUG] Collision in table 7, bucket 11000100... → 2 items
# [DEBUG] Collision in table 8, bucket 01000001... → 2 items
# [DEBUG] Collision in table 9, bucket 01100110... → 2 items
# [DEBUG] Collision in table 10, bucket 01111100... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 10001101... → 2 items
# [DEBUG] Collision in table 13, bucket 11000001... → 2 items
# [DEBUG] Collision in table 14, bucket 01010001... → 2 items
# [DEBUG] Collision in table 15, bucket 01010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00000000... → 3 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00110110... → 2 items
# [DEBUG] Collision in table 20, bucket 00110100... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010100... → 2 items
# [DEBUG] Collision in table 23, bucket 00101100... → 2 items
# [DEBUG] Collision in table 24, bucket 10001100... → 2 items
# [DEBUG] Collision in table 25, bucket 01000000... → 2 items
# [DEBUG] Collision in table 26, bucket 00001100... → 2 items
# [DEBUG] Collision in table 27, bucket 10001000... → 2 items
# [DEBUG] Collision in table 28, bucket 00011001... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 00010110... → 2 items
# [DEBUG] Collision in table 1, bucket 00100000... → 2 items
# [DEBUG] Collision in table 2, bucket 10000000... → 2 items
# [DEBUG] Collision in table 3, bucket 00000110... → 2 items
# [DEBUG] Collision in table 4, bucket 00110000... → 2 items
# [DEBUG] Collision in table 5, bucket 11000000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000011... → 2 items
# [DEBUG] Collision in table 7, bucket 00100010... → 2 items
# [DEBUG] Collision in table 8, bucket 10000001... → 2 items
# [DEBUG] Collision in table 9, bucket 10000110... → 2 items
# [DEBUG] Collision in table 10, bucket 00010100... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 10001000... → 2 items
# [DEBUG] Collision in table 13, bucket 00110001... → 2 items
# [DEBUG] Collision in table 14, bucket 00001010... → 2 items
# [DEBUG] Collision in table 15, bucket 01010101... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00100000... → 2 items
# [DEBUG] Collision in table 19, bucket 00100100... → 2 items
# [DEBUG] Collision in table 20, bucket 00011001... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 00010000... → 2 items
# [DEBUG] Collision in table 23, bucket 10010001... → 2 items
# [DEBUG] Collision in table 24, bucket 10001100... → 2 items
# [DEBUG] Collision in table 25, bucket 10000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00100000... → 2 items
# [DEBUG] Collision in table 27, bucket 00010000... → 2 items
# [DEBUG] Collision in table 28, bucket 10101000... → 2 items
# [DEBUG] Collision in table 29, bucket 01000010... → 2 items
# [DEBUG] Collision in table 0, bucket 00000011... → 2 items
# [DEBUG] Collision in table 1, bucket 00000110... → 2 items
# [DEBUG] Collision in table 2, bucket 10100000... → 2 items
# [DEBUG] Collision in table 3, bucket 00111000... → 2 items
# [DEBUG] Collision in table 4, bucket 00100100... → 2 items
# [DEBUG] Collision in table 5, bucket 01000011... → 2 items
# [DEBUG] Collision in table 6, bucket 00001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 3 items
# [DEBUG] Collision in table 9, bucket 10100110... → 2 items
# [DEBUG] Collision in table 10, bucket 01011000... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 10001000... → 2 items
# [DEBUG] Collision in table 13, bucket 01101000... → 2 items
# [DEBUG] Collision in table 14, bucket 10110001... → 2 items
# [DEBUG] Collision in table 15, bucket 01110100... → 2 items
# [DEBUG] Collision in table 16, bucket 00010000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 3 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00111010... → 2 items
# [DEBUG] Collision in table 20, bucket 00001100... → 2 items
# [DEBUG] Collision in table 21, bucket 10010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010100... → 2 items
# [DEBUG] Collision in table 23, bucket 00010000... → 2 items
# [DEBUG] Collision in table 24, bucket 10101001... → 2 items
# [DEBUG] Collision in table 25, bucket 00000010... → 2 items
# [DEBUG] Collision in table 26, bucket 00001100... → 2 items
# [DEBUG] Collision in table 27, bucket 00100000... → 2 items
# [DEBUG] Collision in table 28, bucket 00000001... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 00010100... → 2 items
# [DEBUG] Collision in table 1, bucket 00100001... → 2 items
# [DEBUG] Collision in table 2, bucket 10100011... → 2 items
# [DEBUG] Collision in table 3, bucket 01010010... → 2 items
# [DEBUG] Collision in table 4, bucket 00010010... → 2 items
# [DEBUG] Collision in table 5, bucket 00111001... → 2 items
# [DEBUG] Collision in table 6, bucket 01000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000011... → 2 items
# [DEBUG] Collision in table 8, bucket 10001101... → 2 items
# [DEBUG] Collision in table 9, bucket 00100011... → 2 items
# [DEBUG] Collision in table 10, bucket 00010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00001000... → 2 items
# [DEBUG] Collision in table 12, bucket 00000001... → 2 items
# [DEBUG] Collision in table 13, bucket 00001100... → 2 items
# [DEBUG] Collision in table 14, bucket 00100000... → 2 items
# [DEBUG] Collision in table 15, bucket 00100101... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00011000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000110... → 2 items
# [DEBUG] Collision in table 19, bucket 00000110... → 2 items
# [DEBUG] Collision in table 20, bucket 10110000... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 00010000... → 2 items
# [DEBUG] Collision in table 23, bucket 00000001... → 2 items
# [DEBUG] Collision in table 24, bucket 00110000... → 2 items
# [DEBUG] Collision in table 25, bucket 00000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00100000... → 2 items
# [DEBUG] Collision in table 27, bucket 01110100... → 2 items
# [DEBUG] Collision in table 28, bucket 10000010... → 2 items
# [DEBUG] Collision in table 29, bucket 00000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10000111... → 2 items
# [DEBUG] Collision in table 1, bucket 00100100... → 2 items
# [DEBUG] Collision in table 2, bucket 10100001... → 2 items
# [DEBUG] Collision in table 3, bucket 00100010... → 2 items
# [DEBUG] Collision in table 4, bucket 00100000... → 2 items
# [DEBUG] Collision in table 5, bucket 00010000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000011... → 2 items
# [DEBUG] Collision in table 7, bucket 00000010... → 2 items
# [DEBUG] Collision in table 8, bucket 00000001... → 2 items
# [DEBUG] Collision in table 9, bucket 00100011... → 2 items
# [DEBUG] Collision in table 10, bucket 01010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00001000... → 2 items
# [DEBUG] Collision in table 12, bucket 00000100... → 2 items
# [DEBUG] Collision in table 13, bucket 01010000... → 2 items
# [DEBUG] Collision in table 14, bucket 00000011... → 2 items
# [DEBUG] Collision in table 15, bucket 11000100... → 2 items
# [DEBUG] Collision in table 16, bucket 00100100... → 2 items
# [DEBUG] Collision in table 17, bucket 00010001... → 2 items
# [DEBUG] Collision in table 18, bucket 01000000... → 2 items
# [DEBUG] Collision in table 19, bucket 00100010... → 2 items
# [DEBUG] Collision in table 20, bucket 10010001... → 2 items
# [DEBUG] Collision in table 21, bucket 00010001... → 2 items
# [DEBUG] Collision in table 22, bucket 00010000... → 2 items
# [DEBUG] Collision in table 23, bucket 10000000... → 2 items
# [DEBUG] Collision in table 24, bucket 00001100... → 2 items
# [DEBUG] Collision in table 25, bucket 10000100... → 2 items
# [DEBUG] Collision in table 26, bucket 00110100... → 2 items
# [DEBUG] Collision in table 27, bucket 00000010... → 2 items
# [DEBUG] Collision in table 28, bucket 00001000... → 2 items
# [DEBUG] Collision in table 29, bucket 01000110... → 2 items
# 🔗 Adding vectors to LSH:   5%|▉                 | 1/20 [00:00<00:04,  3.99it/s]
# [DEBUG] Collision in table 0, bucket 00010011... → 2 items
# [DEBUG] Collision in table 1, bucket 00000010... → 2 items
# [DEBUG] Collision in table 2, bucket 10110001... → 2 items
# [DEBUG] Collision in table 3, bucket 00111000... → 2 items
# [DEBUG] Collision in table 4, bucket 00100000... → 2 items
# [DEBUG] Collision in table 5, bucket 11000001... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 10000000... → 2 items
# [DEBUG] Collision in table 9, bucket 11100110... → 2 items
# [DEBUG] Collision in table 10, bucket 01011011... → 2 items
# [DEBUG] Collision in table 11, bucket 00000101... → 2 items
# [DEBUG] Collision in table 12, bucket 10001001... → 2 items
# [DEBUG] Collision in table 13, bucket 01000000... → 2 items
# [DEBUG] Collision in table 14, bucket 00100001... → 2 items
# [DEBUG] Collision in table 15, bucket 01010100... → 2 items
# [DEBUG] Collision in table 16, bucket 00000000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 4 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00000111... → 2 items
# [DEBUG] Collision in table 20, bucket 00000000... → 2 items
# [DEBUG] Collision in table 21, bucket 10000000... → 2 items
# [DEBUG] Collision in table 22, bucket 00010100... → 2 items
# [DEBUG] Collision in table 23, bucket 00011000... → 2 items
# [DEBUG] Collision in table 24, bucket 10001000... → 2 items
# [DEBUG] Collision in table 25, bucket 01000010... → 2 items
# [DEBUG] Collision in table 26, bucket 00101100... → 2 items
# [DEBUG] Collision in table 27, bucket 01110000... → 2 items
# [DEBUG] Collision in table 28, bucket 00010001... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 11000110... → 2 items
# [DEBUG] Collision in table 1, bucket 00000100... → 2 items
# [DEBUG] Collision in table 2, bucket 10100010... → 2 items
# [DEBUG] Collision in table 3, bucket 00010000... → 2 items
# [DEBUG] Collision in table 4, bucket 00101000... → 2 items
# [DEBUG] Collision in table 5, bucket 00000010... → 2 items
# [DEBUG] Collision in table 6, bucket 00101010... → 2 items
# [DEBUG] Collision in table 7, bucket 00100110... → 2 items
# [DEBUG] Collision in table 8, bucket 00000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100001... → 2 items
# [DEBUG] Collision in table 10, bucket 00111001... → 2 items
# [DEBUG] Collision in table 11, bucket 00001101... → 2 items
# [DEBUG] Collision in table 12, bucket 00001100... → 2 items
# [DEBUG] Collision in table 13, bucket 11100000... → 2 items
# [DEBUG] Collision in table 14, bucket 01000000... → 2 items
# [DEBUG] Collision in table 15, bucket 01010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00101000... → 2 items
# [DEBUG] Collision in table 17, bucket 01000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000000... → 2 items
# [DEBUG] Collision in table 19, bucket 00000010... → 2 items
# [DEBUG] Collision in table 20, bucket 00110101... → 2 items
# [DEBUG] Collision in table 21, bucket 10000000... → 2 items
# [DEBUG] Collision in table 22, bucket 00110100... → 2 items
# [DEBUG] Collision in table 23, bucket 00001000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 00000010... → 2 items
# [DEBUG] Collision in table 26, bucket 00100001... → 2 items
# [DEBUG] Collision in table 27, bucket 00000000... → 2 items
# [DEBUG] Collision in table 28, bucket 10000000... → 2 items
# [DEBUG] Collision in table 29, bucket 01010110... → 2 items
# [DEBUG] Collision in table 0, bucket 10000100... → 2 items
# [DEBUG] Collision in table 1, bucket 00000010... → 2 items
# [DEBUG] Collision in table 2, bucket 11000001... → 2 items
# [DEBUG] Collision in table 3, bucket 10101000... → 2 items
# [DEBUG] Collision in table 4, bucket 00100100... → 2 items
# [DEBUG] Collision in table 5, bucket 00001010... → 2 items
# [DEBUG] Collision in table 6, bucket 00101001... → 2 items
# [DEBUG] Collision in table 7, bucket 01010100... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 4 items
# [DEBUG] Collision in table 9, bucket 00100110... → 2 items
# [DEBUG] Collision in table 10, bucket 01111100... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 00000100... → 2 items
# [DEBUG] Collision in table 13, bucket 01100000... → 2 items
# [DEBUG] Collision in table 14, bucket 01010001... → 2 items
# [DEBUG] Collision in table 15, bucket 00110100... → 2 items
# [DEBUG] Collision in table 16, bucket 00000000... → 4 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00010110... → 2 items
# [DEBUG] Collision in table 20, bucket 00110100... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010101... → 2 items
# [DEBUG] Collision in table 23, bucket 00100100... → 2 items
# [DEBUG] Collision in table 24, bucket 10001000... → 2 items
# [DEBUG] Collision in table 25, bucket 01000000... → 2 items
# [DEBUG] Collision in table 26, bucket 00001100... → 2 items
# [DEBUG] Collision in table 27, bucket 10001000... → 2 items
# [DEBUG] Collision in table 28, bucket 00010001... → 2 items
# [DEBUG] Collision in table 29, bucket 00000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10010110... → 2 items
# [DEBUG] Collision in table 1, bucket 01000000... → 2 items
# [DEBUG] Collision in table 2, bucket 01000000... → 2 items
# [DEBUG] Collision in table 3, bucket 00011001... → 2 items
# [DEBUG] Collision in table 4, bucket 00000000... → 2 items
# [DEBUG] Collision in table 5, bucket 00001100... → 2 items
# [DEBUG] Collision in table 6, bucket 00001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000101... → 2 items
# [DEBUG] Collision in table 8, bucket 10100101... → 2 items
# [DEBUG] Collision in table 9, bucket 00100000... → 2 items
# [DEBUG] Collision in table 10, bucket 01010010... → 2 items
# [DEBUG] Collision in table 11, bucket 00000101... → 2 items
# [DEBUG] Collision in table 12, bucket 00000000... → 2 items
# [DEBUG] Collision in table 13, bucket 11100000... → 2 items
# [DEBUG] Collision in table 14, bucket 00100100... → 2 items
# [DEBUG] Collision in table 15, bucket 00000100... → 2 items
# [DEBUG] Collision in table 16, bucket 00100100... → 2 items
# [DEBUG] Collision in table 17, bucket 10100010... → 2 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00001110... → 2 items
# [DEBUG] Collision in table 20, bucket 00110000... → 2 items
# [DEBUG] Collision in table 21, bucket 10001010... → 2 items
# [DEBUG] Collision in table 22, bucket 01010001... → 2 items
# [DEBUG] Collision in table 23, bucket 00000100... → 2 items
# [DEBUG] Collision in table 24, bucket 00001010... → 2 items
# [DEBUG] Collision in table 25, bucket 00000010... → 2 items
# [DEBUG] Collision in table 26, bucket 00101001... → 2 items
# [DEBUG] Collision in table 27, bucket 00010001... → 2 items
# [DEBUG] Collision in table 28, bucket 10010000... → 2 items
# [DEBUG] Collision in table 29, bucket 10000100... → 2 items
# [DEBUG] Collision in table 0, bucket 00010111... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10110011... → 2 items
# [DEBUG] Collision in table 3, bucket 00010010... → 2 items
# [DEBUG] Collision in table 4, bucket 10100000... → 2 items
# [DEBUG] Collision in table 5, bucket 00001000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 00000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100000... → 2 items
# [DEBUG] Collision in table 10, bucket 01010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00000101... → 2 items
# [DEBUG] Collision in table 12, bucket 11000000... → 2 items
# [DEBUG] Collision in table 13, bucket 00000000... → 2 items
# [DEBUG] Collision in table 14, bucket 00100100... → 2 items
# [DEBUG] Collision in table 15, bucket 10010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000100... → 2 items
# [DEBUG] Collision in table 19, bucket 00000011... → 2 items
# [DEBUG] Collision in table 20, bucket 00001000... → 2 items
# [DEBUG] Collision in table 21, bucket 10011010... → 2 items
# [DEBUG] Collision in table 22, bucket 00011101... → 2 items
# [DEBUG] Collision in table 23, bucket 00001000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100010... → 2 items
# [DEBUG] Collision in table 25, bucket 00001100... → 2 items
# [DEBUG] Collision in table 26, bucket 01000001... → 2 items
# [DEBUG] Collision in table 27, bucket 01010010... → 2 items
# [DEBUG] Collision in table 28, bucket 00000000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000010... → 2 items
# [DEBUG] Collision in table 0, bucket 00001110... → 2 items
# [DEBUG] Collision in table 1, bucket 01000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10000000... → 2 items
# [DEBUG] Collision in table 3, bucket 00010010... → 2 items
# [DEBUG] Collision in table 4, bucket 00100000... → 2 items
# [DEBUG] Collision in table 5, bucket 01000000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00100010... → 2 items
# [DEBUG] Collision in table 8, bucket 10000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10000110... → 2 items
# [DEBUG] Collision in table 10, bucket 01010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00000101... → 2 items
# [DEBUG] Collision in table 12, bucket 00001000... → 2 items
# [DEBUG] Collision in table 13, bucket 11100001... → 2 items
# [DEBUG] Collision in table 14, bucket 00011010... → 2 items
# [DEBUG] Collision in table 15, bucket 11010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00100001... → 2 items
# [DEBUG] Collision in table 17, bucket 10000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00001100... → 2 items
# [DEBUG] Collision in table 20, bucket 00011001... → 2 items
# [DEBUG] Collision in table 21, bucket 10010000... → 2 items
# [DEBUG] Collision in table 22, bucket 00011000... → 2 items
# [DEBUG] Collision in table 23, bucket 00010100... → 2 items
# [DEBUG] Collision in table 24, bucket 11001110... → 2 items
# [DEBUG] Collision in table 25, bucket 01000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00100010... → 2 items
# [DEBUG] Collision in table 27, bucket 00010000... → 2 items
# [DEBUG] Collision in table 28, bucket 10100000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000100... → 2 items
# [DEBUG] Collision in table 0, bucket 10000101... → 2 items
# [DEBUG] Collision in table 1, bucket 00001101... → 2 items
# [DEBUG] Collision in table 2, bucket 10100010... → 2 items
# [DEBUG] Collision in table 3, bucket 10000000... → 2 items
# [DEBUG] Collision in table 4, bucket 01101000... → 2 items
# [DEBUG] Collision in table 5, bucket 10000000... → 2 items
# [DEBUG] Collision in table 6, bucket 01001000... → 2 items
# [DEBUG] Collision in table 7, bucket 10100010... → 2 items
# [DEBUG] Collision in table 8, bucket 10000001... → 2 items
# [DEBUG] Collision in table 9, bucket 10100010... → 2 items
# [DEBUG] Collision in table 10, bucket 00100110... → 2 items
# [DEBUG] Collision in table 11, bucket 00001000... → 2 items
# [DEBUG] Collision in table 12, bucket 11010101... → 2 items
# [DEBUG] Collision in table 13, bucket 10100000... → 2 items
# [DEBUG] Collision in table 14, bucket 00101100... → 2 items
# [DEBUG] Collision in table 15, bucket 01000000... → 2 items
# [DEBUG] Collision in table 16, bucket 10110101... → 2 items
# [DEBUG] Collision in table 17, bucket 01010000... → 2 items
# [DEBUG] Collision in table 18, bucket 11000000... → 2 items
# [DEBUG] Collision in table 19, bucket 00101000... → 2 items
# [DEBUG] Collision in table 20, bucket 00010111... → 2 items
# [DEBUG] Collision in table 21, bucket 10000010... → 2 items
# [DEBUG] Collision in table 22, bucket 10010100... → 2 items
# [DEBUG] Collision in table 23, bucket 10000100... → 2 items
# [DEBUG] Collision in table 24, bucket 00101010... → 2 items
# [DEBUG] Collision in table 25, bucket 00000110... → 2 items
# [DEBUG] Collision in table 26, bucket 11000000... → 2 items
# [DEBUG] Collision in table 27, bucket 00010000... → 2 items
# [DEBUG] Collision in table 28, bucket 01010000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000010... → 2 items
# [DEBUG] Collision in table 2, bucket 10100000... → 3 items
# [DEBUG] Collision in table 0, bucket 10000010... → 2 items
# [DEBUG] Collision in table 1, bucket 00001000... → 2 items
# [DEBUG] Collision in table 2, bucket 11000001... → 2 items
# [DEBUG] Collision in table 3, bucket 10011000... → 2 items
# [DEBUG] Collision in table 4, bucket 00100100... → 2 items
# [DEBUG] Collision in table 5, bucket 01000010... → 2 items
# [DEBUG] Collision in table 6, bucket 00001001... → 2 items
# [DEBUG] Collision in table 7, bucket 01000000... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 2 items
# [DEBUG] Collision in table 9, bucket 00100110... → 2 items
# [DEBUG] Collision in table 10, bucket 01011100... → 2 items
# [DEBUG] Collision in table 11, bucket 00000001... → 2 items
# [DEBUG] Collision in table 12, bucket 00000100... → 2 items
# [DEBUG] Collision in table 13, bucket 01100000... → 2 items
# [DEBUG] Collision in table 14, bucket 00110001... → 2 items
# [DEBUG] Collision in table 15, bucket 10010100... → 2 items
# [DEBUG] Collision in table 16, bucket 00010100... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00010110... → 2 items
# [DEBUG] Collision in table 20, bucket 00010000... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010001... → 2 items
# [DEBUG] Collision in table 23, bucket 00100100... → 2 items
# [DEBUG] Collision in table 24, bucket 10101011... → 2 items
# [DEBUG] Collision in table 25, bucket 01000000... → 2 items
# [DEBUG] Collision in table 26, bucket 00001100... → 2 items
# [DEBUG] Collision in table 27, bucket 00001000... → 2 items
# [DEBUG] Collision in table 28, bucket 10000001... → 2 items
# [DEBUG] Collision in table 29, bucket 10000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10000111... → 2 items
# [DEBUG] Collision in table 1, bucket 00100100... → 2 items
# [DEBUG] Collision in table 2, bucket 10010010... → 2 items
# [DEBUG] Collision in table 3, bucket 01000010... → 2 items
# [DEBUG] Collision in table 4, bucket 00110000... → 2 items
# [DEBUG] Collision in table 5, bucket 00010000... → 2 items
# [DEBUG] Collision in table 6, bucket 00001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 10000001... → 2 items
# [DEBUG] Collision in table 9, bucket 10100010... → 2 items
# [DEBUG] Collision in table 10, bucket 01011010... → 2 items
# [DEBUG] Collision in table 11, bucket 00001101... → 2 items
# [DEBUG] Collision in table 12, bucket 00001100... → 2 items
# [DEBUG] Collision in table 13, bucket 11000000... → 2 items
# [DEBUG] Collision in table 14, bucket 00000100... → 2 items
# [DEBUG] Collision in table 15, bucket 11010100... → 2 items
# [DEBUG] Collision in table 16, bucket 00100101... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 10100000... → 2 items
# [DEBUG] Collision in table 19, bucket 00001010... → 2 items
# [DEBUG] Collision in table 20, bucket 00010000... → 2 items
# [DEBUG] Collision in table 21, bucket 10011010... → 2 items
# [DEBUG] Collision in table 22, bucket 00010000... → 2 items
# [DEBUG] Collision in table 23, bucket 10000000... → 2 items
# [DEBUG] Collision in table 24, bucket 00000010... → 2 items
# [DEBUG] Collision in table 25, bucket 00000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00000000... → 2 items
# [DEBUG] Collision in table 27, bucket 01000100... → 2 items
# [DEBUG] Collision in table 28, bucket 10000000... → 2 items
# [DEBUG] Collision in table 29, bucket 01000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10010110... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10100000... → 2 items
# [DEBUG] Collision in table 3, bucket 00000010... → 2 items
# [DEBUG] Collision in table 4, bucket 00100000... → 2 items
# [DEBUG] Collision in table 5, bucket 10000000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000001... → 2 items
# [DEBUG] Collision in table 7, bucket 00000010... → 2 items
# [DEBUG] Collision in table 8, bucket 10000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10001010... → 2 items
# [DEBUG] Collision in table 10, bucket 00011101... → 2 items
# [DEBUG] Collision in table 11, bucket 00000101... → 2 items
# [DEBUG] Collision in table 12, bucket 00000000... → 2 items
# [DEBUG] Collision in table 13, bucket 00000001... → 2 items
# [DEBUG] Collision in table 14, bucket 00000010... → 2 items
# [DEBUG] Collision in table 15, bucket 10010010... → 2 items
# [DEBUG] Collision in table 16, bucket 10100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00100000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000000... → 2 items
# [DEBUG] Collision in table 19, bucket 00000000... → 2 items
# [DEBUG] Collision in table 20, bucket 00011001... → 2 items
# [DEBUG] Collision in table 21, bucket 10000110... → 2 items
# [DEBUG] Collision in table 22, bucket 10010100... → 2 items
# [DEBUG] Collision in table 23, bucket 10000001... → 2 items
# [DEBUG] Collision in table 24, bucket 00001010... → 2 items
# [DEBUG] Collision in table 25, bucket 00000100... → 2 items
# [DEBUG] Collision in table 26, bucket 01000000... → 2 items
# [DEBUG] Collision in table 27, bucket 00010011... → 2 items
# [DEBUG] Collision in table 28, bucket 10100000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000100... → 2 items
# [DEBUG] Collision in table 0, bucket 00000000... → 2 items
# [DEBUG] Collision in table 1, bucket 00100001... → 2 items
# [DEBUG] Collision in table 2, bucket 10100011... → 2 items
# [DEBUG] Collision in table 3, bucket 00010010... → 2 items
# [DEBUG] Collision in table 4, bucket 00010010... → 2 items
# [DEBUG] Collision in table 5, bucket 00111000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00001000... → 2 items
# [DEBUG] Collision in table 8, bucket 01000110... → 2 items
# [DEBUG] Collision in table 9, bucket 00100011... → 2 items
# [DEBUG] Collision in table 10, bucket 00010000... → 2 items
# [DEBUG] Collision in table 11, bucket 00001100... → 2 items
# [DEBUG] Collision in table 12, bucket 10000101... → 2 items
# [DEBUG] Collision in table 13, bucket 10000100... → 2 items
# [DEBUG] Collision in table 14, bucket 01100100... → 2 items
# [DEBUG] Collision in table 15, bucket 00000101... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00011000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00000010... → 2 items
# [DEBUG] Collision in table 20, bucket 00110000... → 2 items
# [DEBUG] Collision in table 21, bucket 01100000... → 2 items
# [DEBUG] Collision in table 22, bucket 00000000... → 2 items
# [DEBUG] Collision in table 23, bucket 00010001... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 00000100... → 2 items
# [DEBUG] Collision in table 26, bucket 00001000... → 2 items
# [DEBUG] Collision in table 27, bucket 01110100... → 2 items
# [DEBUG] Collision in table 28, bucket 10000010... → 2 items
# [DEBUG] Collision in table 29, bucket 00000010... → 2 items
# [DEBUG] Collision in table 0, bucket 00110000... → 2 items
# [DEBUG] Collision in table 1, bucket 00100001... → 2 items
# [DEBUG] Collision in table 2, bucket 00110011... → 2 items
# [DEBUG] Collision in table 3, bucket 00000010... → 2 items
# [DEBUG] Collision in table 4, bucket 00010000... → 2 items
# [DEBUG] Collision in table 5, bucket 00110000... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000001... → 2 items
# [DEBUG] Collision in table 8, bucket 10000010... → 2 items
# [DEBUG] Collision in table 9, bucket 00100000... → 2 items
# [DEBUG] Collision in table 10, bucket 00010001... → 2 items
# [DEBUG] Collision in table 11, bucket 01000000... → 2 items
# [DEBUG] Collision in table 12, bucket 00010010... → 2 items
# [DEBUG] Collision in table 13, bucket 10110100... → 2 items
# [DEBUG] Collision in table 14, bucket 01100000... → 2 items
# [DEBUG] Collision in table 15, bucket 00100101... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00111000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000110... → 2 items
# [DEBUG] Collision in table 19, bucket 00000010... → 2 items
# [DEBUG] Collision in table 20, bucket 10100000... → 2 items
# [DEBUG] Collision in table 21, bucket 01010010... → 2 items
# [DEBUG] Collision in table 22, bucket 00000100... → 2 items
# [DEBUG] Collision in table 23, bucket 00000000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 00010100... → 2 items
# [DEBUG] Collision in table 26, bucket 01101000... → 2 items
# [DEBUG] Collision in table 27, bucket 01111000... → 2 items
# [DEBUG] Collision in table 28, bucket 00000010... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 10011111... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10010010... → 2 items
# [DEBUG] Collision in table 3, bucket 01000010... → 2 items
# [DEBUG] Collision in table 4, bucket 00100000... → 2 items
# [DEBUG] Collision in table 5, bucket 10010010... → 2 items
# [DEBUG] Collision in table 6, bucket 01001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00100000... → 2 items
# [DEBUG] Collision in table 8, bucket 10000001... → 2 items
# [DEBUG] Collision in table 9, bucket 10101110... → 2 items
# [DEBUG] Collision in table 10, bucket 00111000... → 2 items
# [DEBUG] Collision in table 11, bucket 10001101... → 2 items
# [DEBUG] Collision in table 12, bucket 10001000... → 2 items
# [DEBUG] Collision in table 13, bucket 00000000... → 2 items
# [DEBUG] Collision in table 14, bucket 01000010... → 2 items
# [DEBUG] Collision in table 15, bucket 00010000... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 10110010... → 2 items
# [DEBUG] Collision in table 19, bucket 00000010... → 2 items
# [DEBUG] Collision in table 20, bucket 00110110... → 2 items
# [DEBUG] Collision in table 21, bucket 00001010... → 2 items
# [DEBUG] Collision in table 22, bucket 00110100... → 2 items
# [DEBUG] Collision in table 23, bucket 10001000... → 2 items
# [DEBUG] Collision in table 24, bucket 00001010... → 2 items
# [DEBUG] Collision in table 25, bucket 10001110... → 2 items
# [DEBUG] Collision in table 26, bucket 00000000... → 2 items
# [DEBUG] Collision in table 27, bucket 00010100... → 2 items
# [DEBUG] Collision in table 28, bucket 10000000... → 2 items
# [DEBUG] Collision in table 29, bucket 01000010... → 2 items
# [DEBUG] Collision in table 0, bucket 11000010... → 2 items
# [DEBUG] Collision in table 1, bucket 00000100... → 2 items
# [DEBUG] Collision in table 2, bucket 10010010... → 2 items
# [DEBUG] Collision in table 3, bucket 00000011... → 2 items
# [DEBUG] Collision in table 4, bucket 01100000... → 2 items
# [DEBUG] Collision in table 5, bucket 10000010... → 2 items
# [DEBUG] Collision in table 6, bucket 00101001... → 2 items
# [DEBUG] Collision in table 7, bucket 10001001... → 2 items
# [DEBUG] Collision in table 8, bucket 00000101... → 2 items
# [DEBUG] Collision in table 9, bucket 10000000... → 2 items
# [DEBUG] Collision in table 10, bucket 01001010... → 2 items
# [DEBUG] Collision in table 11, bucket 00001101... → 2 items
# [DEBUG] Collision in table 12, bucket 10001100... → 2 items
# [DEBUG] Collision in table 13, bucket 00100000... → 2 items
# [DEBUG] Collision in table 14, bucket 01100100... → 2 items
# [DEBUG] Collision in table 15, bucket 00000000... → 2 items
# [DEBUG] Collision in table 16, bucket 10100001... → 2 items
# [DEBUG] Collision in table 17, bucket 00000010... → 2 items
# [DEBUG] Collision in table 18, bucket 10100000... → 2 items
# [DEBUG] Collision in table 19, bucket 00001010... → 2 items
# [DEBUG] Collision in table 20, bucket 00100110... → 2 items
# [DEBUG] Collision in table 21, bucket 10000000... → 2 items
# [DEBUG] Collision in table 22, bucket 10011100... → 2 items
# [DEBUG] Collision in table 23, bucket 10100000... → 2 items
# [DEBUG] Collision in table 24, bucket 00101010... → 2 items
# [DEBUG] Collision in table 25, bucket 10000000... → 2 items
# [DEBUG] Collision in table 26, bucket 00100010... → 2 items
# [DEBUG] Collision in table 27, bucket 00000000... → 2 items
# [DEBUG] Collision in table 28, bucket 10011001... → 2 items
# [DEBUG] Collision in table 29, bucket 01000010... → 2 items
# [DEBUG] Collision in table 0, bucket 10010101... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10100010... → 2 items
# [DEBUG] Collision in table 3, bucket 01000010... → 2 items
# [DEBUG] Collision in table 4, bucket 00111000... → 2 items
# [DEBUG] Collision in table 5, bucket 01000100... → 2 items
# [DEBUG] Collision in table 6, bucket 01001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 10000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100110... → 2 items
# [DEBUG] Collision in table 10, bucket 00010100... → 2 items
# [DEBUG] Collision in table 11, bucket 00001000... → 2 items
# [DEBUG] Collision in table 12, bucket 00101101... → 2 items
# [DEBUG] Collision in table 13, bucket 10000000... → 2 items
# [DEBUG] Collision in table 14, bucket 00100000... → 2 items
# [DEBUG] Collision in table 15, bucket 10110101... → 2 items
# [DEBUG] Collision in table 16, bucket 00110000... → 2 items
# [DEBUG] Collision in table 17, bucket 00100000... → 2 items
# [DEBUG] Collision in table 18, bucket 00000000... → 2 items
# [DEBUG] Collision in table 19, bucket 00110000... → 2 items
# [DEBUG] Collision in table 20, bucket 00010000... → 2 items
# [DEBUG] Collision in table 21, bucket 01001000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010000... → 2 items
# [DEBUG] Collision in table 23, bucket 10011000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 00000110... → 2 items
# [DEBUG] Collision in table 26, bucket 00100000... → 2 items
# [DEBUG] Collision in table 27, bucket 10010000... → 2 items
# [DEBUG] Collision in table 28, bucket 01011000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000111... → 2 items
# [DEBUG] Collision in table 0, bucket 00001111... → 2 items
# [DEBUG] Collision in table 1, bucket 00000000... → 2 items
# [DEBUG] Collision in table 2, bucket 10100000... → 2 items
# [DEBUG] Collision in table 3, bucket 01000000... → 2 items
# [DEBUG] Collision in table 4, bucket 00110000... → 2 items
# [DEBUG] Collision in table 5, bucket 01001000... → 2 items
# [DEBUG] Collision in table 6, bucket 00001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100100... → 2 items
# [DEBUG] Collision in table 10, bucket 00010100... → 2 items
# [DEBUG] Collision in table 11, bucket 00001001... → 2 items
# [DEBUG] Collision in table 12, bucket 00001001... → 2 items
# [DEBUG] Collision in table 13, bucket 01100001... → 2 items
# [DEBUG] Collision in table 14, bucket 00000011... → 2 items
# [DEBUG] Collision in table 15, bucket 11010100... → 2 items
# [DEBUG] Collision in table 16, bucket 00110000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 01010100... → 2 items
# [DEBUG] Collision in table 19, bucket 00100010... → 2 items
# [DEBUG] Collision in table 20, bucket 10010000... → 2 items
# [DEBUG] Collision in table 21, bucket 00000000... → 2 items
# [DEBUG] Collision in table 22, bucket 00011100... → 2 items
# [DEBUG] Collision in table 23, bucket 00010000... → 2 items
# [DEBUG] Collision in table 24, bucket 00001100... → 2 items
# [DEBUG] Collision in table 25, bucket 00000010... → 2 items
# [DEBUG] Collision in table 26, bucket 00101001... → 2 items
# [DEBUG] Collision in table 27, bucket 10011110... → 2 items
# [DEBUG] Collision in table 28, bucket 00001000... → 2 items
# [DEBUG] Collision in table 29, bucket 00000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10000110... → 2 items
# [DEBUG] Collision in table 1, bucket 00100000... → 2 items
# [DEBUG] Collision in table 2, bucket 10100011... → 2 items
# [DEBUG] Collision in table 3, bucket 00000000... → 2 items
# [DEBUG] Collision in table 4, bucket 10000000... → 2 items
# [DEBUG] Collision in table 5, bucket 00011000... → 2 items
# [DEBUG] Collision in table 6, bucket 00001000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 2 items
# [DEBUG] Collision in table 9, bucket 00100011... → 2 items
# [DEBUG] Collision in table 10, bucket 00010001... → 2 items
# [DEBUG] Collision in table 11, bucket 00001000... → 2 items
# [DEBUG] Collision in table 12, bucket 10000100... → 2 items
# [DEBUG] Collision in table 13, bucket 01100000... → 2 items
# [DEBUG] Collision in table 14, bucket 00100100... → 2 items
# [DEBUG] Collision in table 15, bucket 11000000... → 2 items
# [DEBUG] Collision in table 16, bucket 00100000... → 2 items
# [DEBUG] Collision in table 17, bucket 00011000... → 2 items
# [DEBUG] Collision in table 18, bucket 01000010... → 2 items
# [DEBUG] Collision in table 19, bucket 00110010... → 2 items
# [DEBUG] Collision in table 20, bucket 10010000... → 2 items
# [DEBUG] Collision in table 21, bucket 00010000... → 2 items
# [DEBUG] Collision in table 22, bucket 10010100... → 2 items
# [DEBUG] Collision in table 23, bucket 00000000... → 2 items
# [DEBUG] Collision in table 24, bucket 00100000... → 2 items
# [DEBUG] Collision in table 25, bucket 01000000... → 2 items
# [DEBUG] Collision in table 26, bucket 00110000... → 2 items
# [DEBUG] Collision in table 27, bucket 01100000... → 2 items
# [DEBUG] Collision in table 28, bucket 00000001... → 2 items
# [DEBUG] Collision in table 29, bucket 00000110... → 2 items
# [DEBUG] Collision in table 0, bucket 10000100... → 3 items
# [DEBUG] Collision in table 1, bucket 00000000... → 3 items
# [DEBUG] Collision in table 2, bucket 01000001... → 3 items
# [DEBUG] Collision in table 3, bucket 00111000... → 3 items
# [DEBUG] Collision in table 4, bucket 01100100... → 3 items
# [DEBUG] Collision in table 5, bucket 01001011... → 3 items
# [DEBUG] Collision in table 6, bucket 00101001... → 3 items
# [DEBUG] Collision in table 7, bucket 11000100... → 3 items
# [DEBUG] Collision in table 8, bucket 01000001... → 3 items
# [DEBUG] Collision in table 9, bucket 01100110... → 3 items
# [DEBUG] Collision in table 10, bucket 01111100... → 3 items
# [DEBUG] Collision in table 11, bucket 00000001... → 3 items
# [DEBUG] Collision in table 12, bucket 10001101... → 3 items
# [DEBUG] Collision in table 13, bucket 11000001... → 3 items
# [DEBUG] Collision in table 14, bucket 01010001... → 3 items
# [DEBUG] Collision in table 15, bucket 01010000... → 3 items
# [DEBUG] Collision in table 16, bucket 00000000... → 5 items
# ...
# [DEBUG] Collision in table 6, bucket 00000000... → 4 items
# [DEBUG] Collision in table 7, bucket 00000000... → 4 items
# [DEBUG] Collision in table 8, bucket 01000000... → 4 items
# [DEBUG] Collision in table 9, bucket 10100100... → 4 items
# [DEBUG] Collision in table 10, bucket 00111100... → 4 items
# [DEBUG] Collision in table 11, bucket 00001001... → 4 items
# [DEBUG] Collision in table 12, bucket 10000100... → 4 items
# [DEBUG] Collision in table 13, bucket 11100001... → 4 items
# [DEBUG] Collision in table 14, bucket 01110101... → 4 items
# [DEBUG] Collision in table 15, bucket 10010000... → 4 items
# [DEBUG] Collision in table 16, bucket 00010000... → 4 items
# [DEBUG] Collision in table 17, bucket 00000000... → 4 items
# [DEBUG] Collision in table 18, bucket 10001000... → 4 items
# [DEBUG] Collision in table 19, bucket 00011110... → 4 items
# [DEBUG] Collision in table 20, bucket 00011000... → 4 items
# [DEBUG] Collision in table 21, bucket 10000010... → 4 items
# [DEBUG] Collision in table 22, bucket 00010100... → 4 items
# [DEBUG] Collision in table 23, bucket 00000100... → 4 items
# [DEBUG] Collision in table 24, bucket 00001100... → 4 items
# [DEBUG] Collision in table 25, bucket 00000010... → 4 items
# [DEBUG] Collision in table 26, bucket 00000101... → 4 items
# [DEBUG] Collision in table 27, bucket 01011100... → 4 items
# [DEBUG] Collision in table 28, bucket 10001000... → 4 items
# [DEBUG] Collision in table 29, bucket 00000000... → 4 items
# [DEBUG] Collision in table 0, bucket 00000111... → 5 items
# [DEBUG] Collision in table 1, bucket 00000100... → 5 items
# [DEBUG] Collision in table 2, bucket 11000001... → 5 items
# [DEBUG] Collision in table 3, bucket 00010000... → 5 items
# [DEBUG] Collision in table 4, bucket 00101100... → 5 items
# [DEBUG] Collision in table 5, bucket 00011000... → 5 items
# [DEBUG] Collision in table 6, bucket 00000000... → 5 items
# [DEBUG] Collision in table 7, bucket 00000000... → 5 items
# [DEBUG] Collision in table 8, bucket 01000000... → 5 items
# [DEBUG] Collision in table 9, bucket 10100100... → 5 items
# [DEBUG] Collision in table 10, bucket 00111100... → 5 items
# [DEBUG] Collision in table 11, bucket 00001001... → 5 items
# [DEBUG] Collision in table 12, bucket 10000100... → 5 items
# [DEBUG] Collision in table 13, bucket 11100001... → 5 items
# [DEBUG] Collision in table 14, bucket 01110101... → 5 items
# [DEBUG] Collision in table 15, bucket 10010000... → 5 items
# [DEBUG] Collision in table 16, bucket 00010000... → 5 items
# [DEBUG] Collision in table 17, bucket 00000000... → 5 items
# [DEBUG] Collision in table 18, bucket 10001000... → 5 items
# [DEBUG] Collision in table 19, bucket 00011110... → 5 items
# [DEBUG] Collision in table 20, bucket 00011000... → 5 items
# [DEBUG] Collision in table 21, bucket 10000010... → 5 items
# [DEBUG] Collision in table 22, bucket 00010100... → 5 items
# [DEBUG] Collision in table 23, bucket 00000100... → 5 items
# [DEBUG] Collision in table 24, bucket 00001100... → 5 items
# [DEBUG] Collision in table 25, bucket 00000010... → 5 items
# [DEBUG] Collision in table 26, bucket 00000101... → 5 items
# [DEBUG] Collision in table 27, bucket 01011100... → 5 items
# [DEBUG] Collision in table 28, bucket 10001000... → 5 items
# [DEBUG] Collision in table 29, bucket 00000000... → 5 items
# [DEBUG] Collision in table 25, bucket 00000010... → 3 items
# [DEBUG] Collision in table 7, bucket 00000100... → 3 items
# [DEBUG] Collision in table 0, bucket 00001000... → 4 items
# [DEBUG] Collision in table 1, bucket 00000001... → 4 items
# [DEBUG] Collision in table 2, bucket 00000010... → 4 items
# [DEBUG] Collision in table 16, bucket 00001001... → 4 items
# [DEBUG] Collision in table 20, bucket 00110100... → 4 items
# [DEBUG] Collision in table 26, bucket 00110000... → 4 items
# [DEBUG] Collision in table 27, bucket 10000100... → 4 items
# [DEBUG] Collision in table 29, bucket 01111110... → 4 items
# [DEBUG] Collision in table 8, bucket 00000001... → 2 items
# [DEBUG] Collision in table 1, bucket 00000100... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 10000111... → 2 items
# [DEBUG] Collision in table 21, bucket 10001101... → 3 items
# [DEBUG] Collision in table 0, bucket 00000111... → 2 items
# [DEBUG] Collision in table 1, bucket 00000100... → 3 items
# [DEBUG] Collision in table 2, bucket 01000101... → 2 items
# [DEBUG] Collision in table 3, bucket 00010000... → 2 items
# [DEBUG] Collision in table 4, bucket 01101100... → 2 items
# [DEBUG] Collision in table 5, bucket 01010011... → 2 items
# [DEBUG] Collision in table 6, bucket 00001011... → 2 items
# [DEBUG] Collision in table 7, bucket 00000100... → 2 items
# [DEBUG] Collision in table 8, bucket 01100000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100101... → 2 items
# [DEBUG] Collision in table 10, bucket 00111111... → 2 items
# [DEBUG] Collision in table 11, bucket 00011001... → 2 items
# [DEBUG] Collision in table 12, bucket 00000100... → 2 items
# [DEBUG] Collision in table 13, bucket 11100010... → 2 items
# [DEBUG] Collision in table 14, bucket 00110101... → 2 items
# [DEBUG] Collision in table 15, bucket 10110100... → 2 items
# [DEBUG] Collision in table 16, bucket 00110000... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 3 items
# [DEBUG] Collision in table 18, bucket 10001000... → 2 items
# [DEBUG] Collision in table 19, bucket 00010110... → 2 items
# [DEBUG] Collision in table 20, bucket 10111000... → 2 items
# [DEBUG] Collision in table 21, bucket 10000010... → 2 items
# [DEBUG] Collision in table 22, bucket 00010100... → 2 items
# [DEBUG] Collision in table 23, bucket 00100100... → 2 items
# [DEBUG] Collision in table 24, bucket 00101001... → 2 items
# [DEBUG] Collision in table 25, bucket 00100010... → 2 items
# [DEBUG] Collision in table 26, bucket 00000001... → 2 items
# [DEBUG] Collision in table 27, bucket 01000001... → 2 items
# [DEBUG] Collision in table 28, bucket 10001100... → 2 items
# [DEBUG] Collision in table 29, bucket 00000010... → 2 items
# [DEBUG] Collision in table 17, bucket 10000000... → 2 items
# [DEBUG] Collision in table 8, bucket 11000000... → 3 items
# [DEBUG] Collision in table 0, bucket 00000111... → 2 items
# [DEBUG] Collision in table 2, bucket 01000001... → 2 items
# [DEBUG] Collision in table 4, bucket 00001100... → 2 items
# [DEBUG] Collision in table 5, bucket 00011001... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 01000000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100100... → 2 items
# [DEBUG] Collision in table 10, bucket 00111100... → 2 items
# [DEBUG] Collision in table 11, bucket 00001001... → 2 items
# [DEBUG] Collision in table 12, bucket 10000100... → 2 items
# [DEBUG] Collision in table 13, bucket 11100001... → 2 items
# [DEBUG] Collision in table 14, bucket 01110101... → 2 items
# [DEBUG] Collision in table 15, bucket 10011100... → 2 items
# [DEBUG] Collision in table 17, bucket 00000000... → 2 items
# [DEBUG] Collision in table 18, bucket 10001000... → 2 items
# [DEBUG] Collision in table 19, bucket 00010110... → 2 items
# [DEBUG] Collision in table 20, bucket 00010000... → 2 items
# [DEBUG] Collision in table 21, bucket 10000110... → 2 items
# [DEBUG] Collision in table 22, bucket 00010100... → 2 items
# [DEBUG] Collision in table 24, bucket 00001001... → 2 items
# [DEBUG] Collision in table 25, bucket 00100010... → 2 items
# [DEBUG] Collision in table 26, bucket 00000001... → 2 items
# [DEBUG] Collision in table 27, bucket 01001100... → 2 items
# [DEBUG] Collision in table 28, bucket 10001100... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 10000111... → 2 items
# [DEBUG] Collision in table 1, bucket 00000100... → 2 items
# [DEBUG] Collision in table 2, bucket 11000001... → 2 items
# [DEBUG] Collision in table 3, bucket 00011000... → 2 items
# [DEBUG] Collision in table 4, bucket 00011100... → 2 items
# [DEBUG] Collision in table 5, bucket 00011011... → 2 items
# [DEBUG] Collision in table 6, bucket 00000000... → 2 items
# [DEBUG] Collision in table 7, bucket 00000000... → 2 items
# [DEBUG] Collision in table 8, bucket 01100000... → 2 items
# [DEBUG] Collision in table 9, bucket 10100110... → 2 items
# [DEBUG] Collision in table 10, bucket 00111100... → 2 items
# [DEBUG] Collision in table 12, bucket 10000100... → 2 items
# [DEBUG] Collision in table 13, bucket 11100011... → 2 items
# [DEBUG] Collision in table 14, bucket 00110101... → 2 items
# [DEBUG] Collision in table 15, bucket 10010110... → 2 items
# [DEBUG] Collision in table 16, bucket 00011000... → 2 items
# [DEBUG] Collision in table 17, bucket 01001000... → 2 items
# [DEBUG] Collision in table 18, bucket 10001000... → 2 items
# [DEBUG] Collision in table 19, bucket 00010100... → 2 items
# [DEBUG] Collision in table 20, bucket 00011000... → 2 items
# [DEBUG] Collision in table 21, bucket 10000010... → 2 items
# [DEBUG] Collision in table 22, bucket 00010100... → 2 items
# [DEBUG] Collision in table 24, bucket 00001001... → 2 items
# [DEBUG] Collision in table 26, bucket 00000001... → 2 items
# [DEBUG] Collision in table 27, bucket 01000000... → 2 items
# [DEBUG] Collision in table 28, bucket 11001100... → 2 items
# [DEBUG] Collision in table 29, bucket 00000000... → 2 items
# [DEBUG] Collision in table 0, bucket 10000001... → 4 items
# [DEBUG] Collision in table 1, bucket 00000010... → 4 items
# [DEBUG] Collision in table 2, bucket 01110000... → 4 items
# [DEBUG] Collision in table 3, bucket 00011000... → 5 items
# [DEBUG] Collision in table 4, bucket 00000000... → 5 items
# [DEBUG] Collision in table 6, bucket 00001010... → 4 items
# [DEBUG] Collision in table 7, bucket 00000000... → 4 items
# [DEBUG] Collision in table 8, bucket 10000000... → 4 items
# [DEBUG] Collision in table 9, bucket 01100111... → 5 items
# [DEBUG] Collision in table 10, bucket 00111100... → 5 items
# [DEBUG] Collision in table 11, bucket 01000011... → 5 items
# [DEBUG] Collision in table 12, bucket 00000101... → 4 items
# [DEBUG] Collision in table 13, bucket 01100001... → 4 items
# [DEBUG] Collision in table 14, bucket 01000000... → 5 items
# [DEBUG] Collision in table 15, bucket 11010000... → 4 items
# [DEBUG] Collision in table 16, bucket 00110001... → 5 items
# [DEBUG] Collision in table 17, bucket 00001000... → 5 items
# [DEBUG] Collision in table 20, bucket 00000000... → 4 items
# [DEBUG] Collision in table 22, bucket 00010100... → 4 items
# [DEBUG] Collision in table 23, bucket 00011100... → 4 items
# [DEBUG] Collision in table 24, bucket 11111000... → 4 items
# [DEBUG] Collision in table 25, bucket 00000110... → 5 items
# [DEBUG] Collision in table 26, bucket 00001000... → 5 items
# [DEBUG] Collision in table 27, bucket 00101000... → 4 items
# [DEBUG] Collision in table 28, bucket 10000000... → 5 items
# [DEBUG] Collision in table 0, bucket 10000001... → 4 items
# [DEBUG] Collision in table 1, bucket 00100110... → 4 items
# [DEBUG] Collision in table 2, bucket 01100001... → 4 items
# [DEBUG] Collision in table 3, bucket 00001000... → 4 items
# [DEBUG] Collision in table 4, bucket 00000000... → 5 items
# [DEBUG] Collision in table 6, bucket 00001000... → 4 items
# [DEBUG] Collision in table 7, bucket 00000100... → 5 items
# [DEBUG] Collision in table 8, bucket 00000000... → 5 items
# [DEBUG] Collision in table 9, bucket 00100110... → 4 items
# [DEBUG] Collision in table 11, bucket 01000001... → 5 items
# [DEBUG] Collision in table 12, bucket 10000001... → 4 items
# [DEBUG] Collision in table 13, bucket 11100001... → 4 items
# [DEBUG] Collision in table 14, bucket 01000001... → 4 items
# [DEBUG] Collision in table 15, bucket 10010100... → 4 items
# [DEBUG] Collision in table 16, bucket 00110101... → 4 items
# [DEBUG] Collision in table 17, bucket 00001000... → 4 items
# [DEBUG] Collision in table 18, bucket 00001010... → 4 items
# [DEBUG] Collision in table 19, bucket 01011110... → 4 items
# [DEBUG] Collision in table 20, bucket 00010000... → 4 items
# [DEBUG] Collision in table 21, bucket 10000100... → 5 items
# [DEBUG] Collision in table 22, bucket 00010000... → 5 items
# [DEBUG] Collision in table 23, bucket 00111100... → 4 items
# [DEBUG] Collision in table 24, bucket 11111000... → 4 items
# [DEBUG] Collision in table 26, bucket 00001000... → 4 items
# [DEBUG] Collision in table 27, bucket 00101000... → 5 items
# [DEBUG] Collision in table 28, bucket 11000000... → 4 items
# [DEBUG] Collision in table 0, bucket 10010101... → 4 items
# [DEBUG] Collision in table 2, bucket 01110000... → 4 items
# [DEBUG] Collision in table 5, bucket 01101100... → 4 items
# [DEBUG] Collision in table 7, bucket 00000000... → 4 items
# [DEBUG] Collision in table 8, bucket 00000000... → 4 items
# [DEBUG] Collision in table 9, bucket 11100111... → 4 items
# [DEBUG] Collision in table 14, bucket 01000000... → 4 items
# [DEBUG] Collision in table 16, bucket 00110001... → 4 items
# [DEBUG] Collision in table 19, bucket 01011110... → 4 items
# [DEBUG] Collision in table 22, bucket 00010100... → 4 items
# [DEBUG] Collision in table 23, bucket 00011100... → 5 items
# [DEBUG] Collision in table 26, bucket 00001000... → 4 items
# [DEBUG] Collision in table 0, bucket 00000001... → 4 items
# [DEBUG] Collision in table 2, bucket 01010001... → 5 items
# [DEBUG] Collision in table 3, bucket 10011000... → 4 items
# [DEBUG] Collision in table 4, bucket 00010000... → 4 items
# [DEBUG] Collision in table 5, bucket 00010100... → 4 items
# [DEBUG] Collision in table 6, bucket 00001000... → 4 items
# [DEBUG] Collision in table 7, bucket 00000100... → 4 items
# [DEBUG] Collision in table 9, bucket 01100010... → 4 items
# [DEBUG] Collision in table 10, bucket 00011000... → 4 items
# [DEBUG] Collision in table 11, bucket 01000001... → 4 items
# [DEBUG] Collision in table 12, bucket 10000001... → 4 items
# [DEBUG] Collision in table 13, bucket 11100001... → 4 items
# [DEBUG] Collision in table 14, bucket 01000001... → 4 items
# [DEBUG] Collision in table 15, bucket 11010100... → 4 items
# [DEBUG] Collision in table 16, bucket 00110000... → 4 items
# [DEBUG] Collision in table 18, bucket 01001110... → 4 items
# [DEBUG] Collision in table 19, bucket 01011110... → 4 items
# [DEBUG] Collision in table 20, bucket 00000000... → 5 items
# [DEBUG] Collision in table 21, bucket 10000000... → 4 items
# [DEBUG] Collision in table 22, bucket 00010100... → 4 items
# [DEBUG] Collision in table 23, bucket 00101100... → 4 items
# [DEBUG] Collision in table 26, bucket 00001000... → 4 items
# [DEBUG] Collision in table 27, bucket 00100000... → 5 items
# [DEBUG] Collision in table 28, bucket 01000000... → 4 items
# [DEBUG] Collision in table 29, bucket 00000000... → 4 items
# 🔗 Adding vectors to LSH: 100%|█████████████████| 20/20 [00:05<00:00,  3.88it/s]
# [DEBUG] Collision in table 0, bucket 10010111... → 4 items
# [DEBUG] Collision in table 1, bucket 00000000... → 4 items
# [DEBUG] Collision in table 2, bucket 01110000... → 4 items
# [DEBUG] Collision in table 4, bucket 00000000... → 4 items
# [DEBUG] Collision in table 5, bucket 01101101... → 4 items
# [DEBUG] Collision in table 6, bucket 00001010... → 4 items
# [DEBUG] Collision in table 7, bucket 00000001... → 4 items
# [DEBUG] Collision in table 8, bucket 10000000... → 4 items
# [DEBUG] Collision in table 9, bucket 00100111... → 4 items
# [DEBUG] Collision in table 10, bucket 00111110... → 4 items
# [DEBUG] Collision in table 11, bucket 01000001... → 4 items
# [DEBUG] Collision in table 12, bucket 00000101... → 4 items
# [DEBUG] Collision in table 13, bucket 01101001... → 4 items
# [DEBUG] Collision in table 14, bucket 01000000... → 5 items
# [DEBUG] Collision in table 15, bucket 10010100... → 4 items
# [DEBUG] Collision in table 16, bucket 00110001... → 4 items
# [DEBUG] Collision in table 18, bucket 00001110... → 4 items
# [DEBUG] Collision in table 19, bucket 01011110... → 4 items
# [DEBUG] Collision in table 20, bucket 00000100... → 5 items
# [DEBUG] Collision in table 26, bucket 00000000... → 4 items
# [DEBUG] Collision in table 27, bucket 00101000... → 4 items
# [DEBUG] Collision in table 28, bucket 10000000... → 5 items
# [DEBUG] Collision in table 29, bucket 00000000... → 4 items
# [DEBUG] Added 10000 vectors...
# Saving LSH index to cache...
# Done! Total time: 5.62 sec

# %%
# Out:
# 162835

# %%
import numpy as np
import time
from tqdm import tqdm

def query_lsh(
    lsh,
    dense_vectors,
    filenames,
    query_text,
    model,
    top_k=5,
    similarity_metric="euclidean"
):
    print("\n [STEP 1] Embedding query text...")
    t0 = time.time()

    query_vector = model.encode([query_text])[0]
    nonzero_features = np.count_nonzero(query_vector)

    print(f"  - Query vector shape: {query_vector.shape}")
    print(f"  - Non-zero embedding dimensions: {nonzero_features}")
    if nonzero_features == 0:
        print("Query vector is empty. Try another query.")
        return []

    print("\n [STEP 2] Querying LSH index...")
    candidate_ids = lsh.query(query_vector)
    t1 = time.time()

    print(f" - LSH returned {len(candidate_ids)} candidates in {t1 - t0:.3f} sec")

    if not candidate_ids:
        print(" No candidates found. Possibly due to hash size or vector sparsity.")
        return []

    print("\n [STEP 3] Matching candidate filenames to vectors...")
    candidate_indices = []
    for f in candidate_ids:
        try:
            idx = filenames.index(f)
            candidate_indices.append(idx)
        except ValueError:
            print(f" Candidate {f} not found in filenames list.")

    if not candidate_indices:
        print(" No valid candidate indices found.")
        return []

    candidate_vectors = dense_vectors[candidate_indices]
    print(f"  - Found {len(candidate_vectors)} vectors for comparison.")

    print("\n [STEP 4] Computing distances...")
    distances = []
    for i, vec in enumerate(tqdm(candidate_vectors, desc="Scoring")):
        if similarity_metric == "cosine":
            denom = np.linalg.norm(query_vector) * np.linalg.norm(vec) + 1e-8
            score = 1 - np.dot(query_vector, vec) / denom
        else:
            score = np.linalg.norm(query_vector - vec)
        distances.append((filenames[candidate_indices[i]], score))

    print("\n [STEP 5] Selecting top matches...")
    sorted_results = sorted(distances, key=lambda x: x[1])[:top_k]

    print(f"\n Top-{top_k} nearest results:")
    for name, score in sorted_results:
        print(f"  • {name} → Score: {score:.4f}")

    return sorted_results

# %%
query_text_mit = """
THE SOFTWARE IS PROVIDED “AS IS”, WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES 
OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE AUTHORS OR COPYRIGHT HOLDERS BE
LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN
CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.
"""
query_text_no_license = """
The gentle rustling of leaves echoed through the forest as the sun dipped below the horizon, casting long shadows across the mossy
ground. Birds chirped their final songs of the day while the air grew cooler, carrying the scent of pine and damp earth. It was a
moment of calm, a brief pause in the world's endless motion.
"""

# %%
results = query_lsh(lsh, dense_vectors, sample_filenames, query_text_mit, model, top_k=5)
# Out:
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 1 candidates
# [DEBUG] Table 3 hit → 2 candidates
# [DEBUG] Table 4 hit → 2 candidates
# [DEBUG] Table 6 hit → 1 candidates
# [DEBUG] Table 7 hit → 1 candidates
# [DEBUG] Table 8 hit → 3 candidates
# [DEBUG] Table 9 hit → 1 candidates
# [DEBUG] Table 11 hit → 1 candidates
# [DEBUG] Table 12 hit → 1 candidates
# [DEBUG] Table 13 hit → 2 candidates
# [DEBUG] Table 15 hit → 2 candidates
# [DEBUG] Table 18 hit → 1 candidates
# [DEBUG] Table 19 hit → 1 candidates
# [DEBUG] Table 22 hit → 2 candidates
# [DEBUG] Table 25 hit → 1 candidates
# [DEBUG] Table 28 hit → 3 candidates
# [DEBUG] Table 29 hit → 1 candidates
#  - LSH returned 4 candidates in 0.592 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 4 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 681.59it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • MITNFA/MITNFA-6.txt → Score: 0.0705
#   • Imlib2/Imlib2-20.txt → Score: 0.1726
#   • MITNFA/MITNFA-6_Split_SPDX_Licenses.txt → Score: 0.2865
#   • Intel/Intel-26.txt → Score: 0.5118

# %%
results = query_lsh(lsh, dense_vectors, sample_filenames, query_text_no_license, model, top_k=5)
# Out:
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.087 sec
#  No candidates found. Possibly due to hash size or vector sparsity.

# %% [markdown]
# ## Let's try on some more samples

# %%
import pandas as pd
df = pd.DataFrame(sample_filenames)

# %%
df
# Out:
#                                                    0
# 0      OSL-2.1/OSL-2.1-37_Split_DB_Foss_Licenses.txt
# 1     OSL-2.1/OSL-2.1-117_Split_DB_Foss_Licenses.txt
# 2        OSL-2.1/OSL-2.1-141_Split_SPDX_Licenses.txt
# 3     OSL-2.1/OSL-2.1-206_Split_DB_Foss_Licenses.txt
# 4         OSL-2.1/OSL-2.1-65_Split_SPDX_Licenses.txt
# ...                                              ...
# 9995             GFDL-1.2-only/GFDL-1.2-only-110.txt
# 9996              GFDL-1.2-only/GFDL-1.2-only-14.txt
# 9997             GFDL-1.2-only/GFDL-1.2-only-104.txt
# 9998             GFDL-1.2-only/GFDL-1.2-only-312.txt
# 9999             GFDL-1.2-only/GFDL-1.2-only-306.txt
#
# [10000 rows x 1 columns]

# %%
unique_licenses = sorted({filename.split("/")[0] for filename in sample_filenames})

# %%
len(unique_licenses)
# Out:
# 46

# %%
unique_licenses
# Out:
# ['AAL',
#  'BSD-3-Clause-Clear',
#  'CATOSL',
#  'CC-BY-3.0',
#  'CC-BY-SA-3.0-AT',
#  'CPL-0.5',
#  'CrystalStacker',
#  'FTL',
#  'Ferris-1.2',
#  'GFDL-1.1-no-invariants-or-later',
#  'GFDL-1.2',
#  'GFDL-1.2-invariants-or-later',
#  'GFDL-1.2-only',
#  'GFDL-1.3',
#  'GFDL-1.3-invariants-or-later',
#  'GPL-3.0-only',
#  'GPL-3.0-with-bison-exception',
#  'Imlib2',
#  'Intel',
#  'LiLiQ-P-1.1',
#  'MITNFA',
#  'MX4J',
#  'NCGL-UK-2.0',
#  'NLOD-1.0',
#  'OASIS',
#  'OLDAP-2.1',
#  'OLDAP-2.6',
#  'OLDAP-2.8',
#  'OSL-2.1',
#  'OpenMarket',
#  'Parity-7.0.0',
#  'PostgreSQL',
#  'RealNetworks-EULA',
#  'SCEA',
#  'VIM',
#  'W3C',
#  'WashU',
#  'YPL-1.0',
#  'YPL-1.1',
#  'ZPL-2.0',
#  'ZPL-2.1',
#  'Zed',
#  'ZoneAlarm-EULA',
#  'gnu-javamail-exception',
#  'info-zip',
#  'libtiff']

# %% [markdown]
# ## Take samples for each license and non license too

# %%
import os
import random
from pathlib import Path

project_root = Path("..").resolve()
output_base = project_root / "Combined-Licenses"

def get_license_samples(base_dir):
    license_samples = []
    for subfolder in os.listdir(base_dir):
        full_path = os.path.join(base_dir, subfolder)
        if os.path.isdir(full_path):
            files = [f for f in os.listdir(full_path) if os.path.isfile(os.path.join(full_path, f))]
            if files:
                chosen_file = random.choice(files)
                file_path = os.path.join(full_path, chosen_file)
                with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
                    content = f.read().strip()
                    license_samples.append([content, 1, subfolder])  # Include folder name
    return license_samples

# Non-license texts: label = 0, folder name = None
non_license_texts = [
    "The quick brown fox jumps over the lazy dog.",
    "Artificial intelligence is transforming the world rapidly.",
    "He bought some apples and oranges from the supermarket.",
    "Python is a popular programming language for data science.",
    "The concert will be held at the downtown auditorium.",
    "Mountains are formed by tectonic plate movement.",
    "User authentication is essential for secure systems.",
    "She traveled to Europe last summer with her family.",
    "Electric vehicles are becoming more common in urban areas.",
    "Coffee consumption has increased during remote work periods.",
    "The novel was set in 19th-century London and Paris.",
    "Biology explores the diversity of life on Earth.",
    "He set up a local server for the development team.",
    "They planned to watch the meteor shower on Friday night.",
    "The history of computing dates back to the 1940s.",
    "Nutrition and exercise are crucial for a healthy life.",
    "The package will be delivered within 3-5 business days.",
    "Global warming poses a serious threat to ecosystems.",
    "The cat knocked over a vase while chasing a fly.",
    "Digital art has gained popularity through NFTs."
]
non_license_samples = [[text, 0, None] for text in non_license_texts]

license_samples = get_license_samples(output_base)
combined = license_samples + non_license_samples
random.shuffle(combined)


print(f"Total samples: {len(combined)} (License: {len(license_samples)}, Non-license: {len(non_license_samples)})")
for i, (text, label, folder) in enumerate(combined[:3]):
    print(f"\nSample {i+1} — Label: {label}, Folder: {folder}\n{text[:200]}...")  # Preview first 200 chars
# Out:
# Total samples: 674 (License: 654, Non-license: 20)
#
# Sample 1 — Label: 1, Folder: Interbase
# INTERBASE PUBLIC LICENSE Version 1.0 1 Definitions. 1.0.1 "Commercial Use" means distribution or otherwise making the Covered Code available to a third party. 1.1 ''Contributor'' means each entity tha...
#
# Sample 2 — Label: 1, Folder: Glide
# 3DFX GLIDE Source Code General Public License 1 PREAMBLE This license is for software that provides a 3D graphics application program interface (API).The license is intended to offer terms similar to ...
#
# Sample 3 — Label: 1, Folder: Font-exception-2.0
# As a special exception, if you create a document which uses this font, and embed this font or unaltered portions of this font into the document, this font does not by itself cause the resulting docume...

# %%
def query_lsh_filenames_only(
    lsh,
    dense_vectors,
    filenames,
    query_text,
    model,
    top_k=5,
    similarity_metric="euclidean"
):
    results = query_lsh(
        lsh,
        dense_vectors,
        filenames,
        query_text,
        model,
        top_k=top_k,
        similarity_metric=similarity_metric
    )
    return [name for name, _ in results]

# %%
import pandas as pd

def evaluate_license_classification(dataset, lsh, dense_vectors, filenames, model):
    results = []

    for i, (text, label, folder) in enumerate(tqdm(dataset, desc="🔍 Evaluating Queries")):
        matched_files = query_lsh_filenames_only(
            lsh, dense_vectors, filenames, text, model, top_k=5
        )

        is_match = len(matched_files) > 0
        correct = (label == 1 and is_match) or (label == 0 and not is_match)

        results.append({
            "query_index": i,
            "text_preview": text[:100].replace("\n", " ") + "...",
            "true_label": label,
            "matched_files": matched_files,
            "correct": correct,
            "license_folder": folder
        })

    df_results = pd.DataFrame(results)
    accuracy = df_results["correct"].mean()
    print(f"\n Overall accuracy: {accuracy * 100:.2f}% ({df_results['correct'].sum()}/{len(df_results)})")
    return df_results

# %%
df_eval = evaluate_license_classification(combined, lsh, dense_vectors, sample_filenames, model)
# Out:
# 🔍 Evaluating Queries:   0%|                            | 0/674 [00:00<?, ?it/s]
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   0%|                    | 1/674 [00:01<17:02,  1.52s/it]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.519 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 3 candidates
# [DEBUG] Table 7 hit → 1 candidates
#  - LSH returned 4 candidates in 0.062 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 4 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|███████████████████████████████████| 4/4 [00:00<00:00, 872.04it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-371.txt → Score: 0.9962
#   • SCEA/SCEA-41_Split_SPDX_Licenses.txt → Score: 1.0061
#   • SCEA/SCEA-114.txt → Score: 1.0061
#   • SCEA/SCEA-119.txt → Score: 1.0884
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 22 hit → 1 candidates
#  - LSH returned 1 candidates in 0.458 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 14122.24it/s]
# 🔍 Evaluating Queries:   0%|                    | 3/674 [00:02<06:37,  1.69it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • gnu-javamail-exception/gnu-javamail-exception-3_Split_SPDX_Licenses.txt → Score: 0.9034
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   1%|                    | 4/674 [00:02<05:25,  2.06it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.285 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   1%|▏                   | 5/674 [00:02<04:40,  2.38it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.286 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 3 candidates
# [DEBUG] Table 7 hit → 3 candidates
# [DEBUG] Table 8 hit → 5 candidates
# [DEBUG] Table 12 hit → 1 candidates
# [DEBUG] Table 13 hit → 1 candidates
# [DEBUG] Table 18 hit → 1 candidates
# [DEBUG] Table 21 hit → 3 candidates
# [DEBUG] Table 27 hit → 1 candidates
#  - LSH returned 7 candidates in 0.373 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 7 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 7/7 [00:00<00:00, 75475.91it/s]
# 🔍 Evaluating Queries:   1%|▏                   | 6/674 [00:03<04:31,  2.46it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • BSD-3-Clause-Clear/BSD-3-Clause-Clear-8.txt → Score: 0.2593
#   • ZPL-2.1/ZPL-2.1-26.txt → Score: 0.3482
#   • ZPL-2.1/ZPL-21-33.txt → Score: 0.3482
#   • info-zip/info-zip-28.txt → Score: 0.3521
#   • info-zip/info-zip-28_Split_DB_Foss_Licenses.txt → Score: 0.3521
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 3 candidates
#  - LSH returned 3 candidates in 0.033 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 3 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 3/3 [00:00<00:00, 38362.54it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • Ferris-1.2/Ferris-1.2-412.txt → Score: 1.0884
#   • GFDL-1.3/GFDL-1.3-489.txt → Score: 1.1151
#   • Ferris-1.2/Ferris-1.2-403.txt → Score: 1.1446
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 42 candidates
# [DEBUG] Table 1 hit → 83 candidates
# [DEBUG] Table 2 hit → 40 candidates
# [DEBUG] Table 3 hit → 40 candidates
# [DEBUG] Table 4 hit → 42 candidates
# [DEBUG] Table 5 hit → 42 candidates
# [DEBUG] Table 6 hit → 40 candidates
# [DEBUG] Table 7 hit → 42 candidates
# [DEBUG] Table 8 hit → 46 candidates
# [DEBUG] Table 9 hit → 42 candidates
# [DEBUG] Table 10 hit → 40 candidates
# [DEBUG] Table 11 hit → 42 candidates
# [DEBUG] Table 12 hit → 40 candidates
# [DEBUG] Table 13 hit → 40 candidates
# [DEBUG] Table 14 hit → 42 candidates
# [DEBUG] Table 15 hit → 44 candidates
# [DEBUG] Table 16 hit → 42 candidates
# [DEBUG] Table 17 hit → 45 candidates
# [DEBUG] Table 18 hit → 104 candidates
# [DEBUG] Table 19 hit → 102 candidates
# [DEBUG] Table 20 hit → 40 candidates
# [DEBUG] Table 21 hit → 80 candidates
# [DEBUG] Table 22 hit → 45 candidates
# [DEBUG] Table 23 hit → 42 candidates
# [DEBUG] Table 24 hit → 42 candidates
# [DEBUG] Table 25 hit → 84 candidates
# [DEBUG] Table 26 hit → 86 candidates
# [DEBUG] Table 27 hit → 42 candidates
# [DEBUG] Table 28 hit → 42 candidates
# [DEBUG] Table 29 hit → 42 candidates
#  - LSH returned 167 candidates in 0.022 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 167 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 167/167 [00:00<00:00, 162328.80it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • OLDAP-2.6/OLDAP-2.6-27.txt → Score: 0.0000
#   • OLDAP-2.6/OLDAP-2.6-3_Split_SPDX_Licenses.txt → Score: 0.0000
#   • OLDAP-2.6/OLDAP-2.6-25.txt → Score: 0.0000
#   • OLDAP-2.6/OLDAP-2.6-24.txt → Score: 0.0000
#   • OLDAP-2.6/OLDAP-2.6-26.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 2885 candidates
# [DEBUG] Table 1 hit → 1233 candidates
# [DEBUG] Table 2 hit → 1236 candidates
# [DEBUG] Table 3 hit → 1236 candidates
# [DEBUG] Table 4 hit → 1567 candidates
# [DEBUG] Table 5 hit → 1236 candidates
# [DEBUG] Table 6 hit → 1236 candidates
# [DEBUG] Table 7 hit → 2885 candidates
# [DEBUG] Table 8 hit → 1236 candidates
# [DEBUG] Table 9 hit → 1236 candidates
# [DEBUG] Table 10 hit → 1236 candidates
# [DEBUG] Table 11 hit → 1233 candidates
# [DEBUG] Table 12 hit → 1233 candidates
# [DEBUG] Table 13 hit → 1242 candidates
# [DEBUG] Table 14 hit → 1236 candidates
# [DEBUG] Table 15 hit → 1236 candidates
# [DEBUG] Table 16 hit → 1236 candidates
# [DEBUG] Table 17 hit → 2889 candidates
# [DEBUG] Table 18 hit → 2555 candidates
# [DEBUG] Table 19 hit → 1236 candidates
# [DEBUG] Table 20 hit → 1236 candidates
# [DEBUG] Table 21 hit → 1233 candidates
# [DEBUG] Table 22 hit → 2558 candidates
# [DEBUG] Table 23 hit → 1233 candidates
# [DEBUG] Table 24 hit → 1559 candidates
# [DEBUG] Table 25 hit → 1246 candidates
# [DEBUG] Table 26 hit → 1236 candidates
# [DEBUG] Table 27 hit → 1236 candidates
# [DEBUG] Table 28 hit → 1233 candidates
# [DEBUG] Table 29 hit → 1563 candidates
#  - LSH returned 2900 candidates in 0.032 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 2900 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|██████████████████████████| 2900/2900 [00:00<00:00, 115509.35it/s]
# 🔍 Evaluating Queries:   1%|▎                   | 9/674 [00:03<02:41,  4.12it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GFDL-1.3/GFDL-1.3-265.txt → Score: 0.0000
#   • GFDL-1.3/GFDL-1.3-363_Split_SPDX_Licenses.txt → Score: 0.0000
#   • GFDL-1.3/GFDL-1.3-188_Split_SPDX_Licenses.txt → Score: 0.0000
#   • GFDL-1.3-invariants-or-later/GFDL-1.3-invariants-or-later-276.txt → Score: 0.0000
#   • GFDL-1.3/GFDL-1.3-276_Split_SPDX_Licenses.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 5 candidates
# [DEBUG] Table 1 hit → 5 candidates
# [DEBUG] Table 2 hit → 5 candidates
# [DEBUG] Table 3 hit → 5 candidates
# [DEBUG] Table 4 hit → 5 candidates
# [DEBUG] Table 5 hit → 5 candidates
# [DEBUG] Table 6 hit → 5 candidates
# [DEBUG] Table 7 hit → 5 candidates
# [DEBUG] Table 8 hit → 5 candidates
# [DEBUG] Table 9 hit → 5 candidates
# [DEBUG] Table 10 hit → 5 candidates
# [DEBUG] Table 11 hit → 5 candidates
# [DEBUG] Table 12 hit → 5 candidates
# [DEBUG] Table 13 hit → 5 candidates
# [DEBUG] Table 14 hit → 5 candidates
# [DEBUG] Table 15 hit → 5 candidates
# [DEBUG] Table 16 hit → 5 candidates
# [DEBUG] Table 17 hit → 5 candidates
# [DEBUG] Table 18 hit → 5 candidates
# [DEBUG] Table 19 hit → 5 candidates
# [DEBUG] Table 20 hit → 5 candidates
# [DEBUG] Table 21 hit → 5 candidates
# [DEBUG] Table 22 hit → 5 candidates
# [DEBUG] Table 23 hit → 5 candidates
# [DEBUG] Table 24 hit → 5 candidates
# [DEBUG] Table 25 hit → 5 candidates
# [DEBUG] Table 26 hit → 5 candidates
# [DEBUG] Table 27 hit → 5 candidates
# [DEBUG] Table 28 hit → 5 candidates
# [DEBUG] Table 29 hit → 5 candidates
#  - LSH returned 5 candidates in 2.069 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 5 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 5/5 [00:00<00:00, 18641.35it/s]
# 🔍 Evaluating Queries:   1%|▎                  | 10/674 [00:05<07:04,  1.56it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-109.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-78.txt → Score: 0.0000
#   • ZoneAlarm-EULA/ZoneAlarm-EULA-510.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-83.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-87.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   2%|▎                  | 11/674 [00:07<09:57,  1.11it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.748 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   2%|▎                  | 12/674 [00:08<11:48,  1.07s/it]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.574 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 234 candidates
# [DEBUG] Table 1 hit → 472 candidates
# [DEBUG] Table 2 hit → 472 candidates
# [DEBUG] Table 3 hit → 472 candidates
# [DEBUG] Table 4 hit → 472 candidates
# [DEBUG] Table 5 hit → 472 candidates
# [DEBUG] Table 6 hit → 472 candidates
# [DEBUG] Table 7 hit → 472 candidates
# [DEBUG] Table 8 hit → 472 candidates
# [DEBUG] Table 9 hit → 472 candidates
# [DEBUG] Table 10 hit → 234 candidates
# [DEBUG] Table 11 hit → 472 candidates
# [DEBUG] Table 12 hit → 472 candidates
# [DEBUG] Table 13 hit → 472 candidates
# [DEBUG] Table 14 hit → 472 candidates
# [DEBUG] Table 15 hit → 472 candidates
# [DEBUG] Table 16 hit → 472 candidates
# [DEBUG] Table 17 hit → 472 candidates
# [DEBUG] Table 18 hit → 472 candidates
# [DEBUG] Table 19 hit → 472 candidates
# [DEBUG] Table 20 hit → 472 candidates
# [DEBUG] Table 21 hit → 472 candidates
# [DEBUG] Table 22 hit → 472 candidates
# [DEBUG] Table 23 hit → 472 candidates
# [DEBUG] Table 24 hit → 472 candidates
# [DEBUG] Table 25 hit → 472 candidates
# [DEBUG] Table 26 hit → 472 candidates
# [DEBUG] Table 27 hit → 472 candidates
# [DEBUG] Table 28 hit → 234 candidates
# [DEBUG] Table 29 hit → 472 candidates
#  - LSH returned 472 candidates in 0.036 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 472 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 472/472 [00:00<00:00, 201970.16it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • YPL-1.1/YPL-1.1-108.txt → Score: 0.0000
#   • YPL-1.1/YPL-1.1-92.txt → Score: 0.0000
#   • YPL-1.1/YPL-1.1-26_Split_SPDX_Licenses.txt → Score: 0.0000
#   • YPL-1.1/YPL-1.1-1.txt → Score: 0.0000
#   • YPL-1.1/YPL-1.1-55.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   2%|▍                  | 14/674 [00:09<07:23,  1.49it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.162 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 3 hit → 1 candidates
#  - LSH returned 1 candidates in 0.043 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|██████████████████████████████████| 1/1 [00:00<00:00, 7463.17it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • AAL/AAL-17.txt → Score: 0.9957
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   2%|▍                  | 16/674 [00:09<05:56,  1.84it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.604 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.018 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 5 candidates
# [DEBUG] Table 1 hit → 5 candidates
# [DEBUG] Table 2 hit → 5 candidates
# [DEBUG] Table 3 hit → 5 candidates
# [DEBUG] Table 4 hit → 5 candidates
# [DEBUG] Table 5 hit → 5 candidates
# [DEBUG] Table 6 hit → 5 candidates
# [DEBUG] Table 7 hit → 5 candidates
# [DEBUG] Table 8 hit → 5 candidates
# [DEBUG] Table 9 hit → 5 candidates
# [DEBUG] Table 10 hit → 5 candidates
# [DEBUG] Table 11 hit → 5 candidates
# [DEBUG] Table 12 hit → 5 candidates
# [DEBUG] Table 13 hit → 5 candidates
# [DEBUG] Table 14 hit → 5 candidates
# [DEBUG] Table 15 hit → 5 candidates
# [DEBUG] Table 16 hit → 5 candidates
# [DEBUG] Table 17 hit → 5 candidates
# [DEBUG] Table 18 hit → 5 candidates
# [DEBUG] Table 19 hit → 5 candidates
# [DEBUG] Table 20 hit → 5 candidates
# [DEBUG] Table 21 hit → 5 candidates
# [DEBUG] Table 22 hit → 5 candidates
# [DEBUG] Table 23 hit → 5 candidates
# [DEBUG] Table 24 hit → 5 candidates
# [DEBUG] Table 25 hit → 5 candidates
# [DEBUG] Table 26 hit → 5 candidates
# [DEBUG] Table 27 hit → 5 candidates
# [DEBUG] Table 28 hit → 5 candidates
# [DEBUG] Table 29 hit → 5 candidates
#  - LSH returned 5 candidates in 0.017 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 5 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 5/5 [00:00<00:00, 17360.53it/s]
# 🔍 Evaluating Queries:   3%|▌                  | 19/674 [00:09<03:29,  3.13it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-109.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-78.txt → Score: 0.0000
#   • ZoneAlarm-EULA/ZoneAlarm-EULA-510.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-83.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-87.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.084 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 1 candidates
#  - LSH returned 1 candidates in 0.017 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 12052.60it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • Ferris-1.2/Ferris-1.2-419.txt → Score: 1.0815
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 24 hit → 3 candidates
#  - LSH returned 3 candidates in 0.052 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 3 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 3/3 [00:00<00:00, 25627.11it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GFDL-1.3/GFDL-1.3-369_Split_SPDX_Licenses.txt → Score: 0.8469
#   • GFDL-1.3-invariants-or-later/GFDL-1.3-invariants-or-later-369.txt → Score: 0.8469
#   • GFDL-1.3/GFDL-1.3-386.txt → Score: 0.8469
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 5 candidates
# [DEBUG] Table 1 hit → 5 candidates
# [DEBUG] Table 2 hit → 6 candidates
# [DEBUG] Table 3 hit → 5 candidates
# [DEBUG] Table 4 hit → 5 candidates
# [DEBUG] Table 5 hit → 5 candidates
# [DEBUG] Table 6 hit → 5 candidates
# [DEBUG] Table 7 hit → 5 candidates
# [DEBUG] Table 8 hit → 5 candidates
# [DEBUG] Table 9 hit → 5 candidates
# [DEBUG] Table 10 hit → 5 candidates
# [DEBUG] Table 11 hit → 5 candidates
# [DEBUG] Table 12 hit → 5 candidates
# [DEBUG] Table 13 hit → 5 candidates
# [DEBUG] Table 14 hit → 6 candidates
# [DEBUG] Table 15 hit → 5 candidates
# [DEBUG] Table 16 hit → 5 candidates
# [DEBUG] Table 17 hit → 5 candidates
# [DEBUG] Table 18 hit → 5 candidates
# [DEBUG] Table 19 hit → 5 candidates
# [DEBUG] Table 20 hit → 5 candidates
# [DEBUG] Table 21 hit → 5 candidates
# [DEBUG] Table 22 hit → 6 candidates
# [DEBUG] Table 23 hit → 5 candidates
# [DEBUG] Table 24 hit → 5 candidates
# [DEBUG] Table 25 hit → 5 candidates
# [DEBUG] Table 26 hit → 5 candidates
# [DEBUG] Table 27 hit → 5 candidates
# [DEBUG] Table 28 hit → 5 candidates
# [DEBUG] Table 29 hit → 6 candidates
#  - LSH returned 6 candidates in 0.200 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 6 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 6/6 [00:00<00:00, 42871.93it/s]
# 🔍 Evaluating Queries:   3%|▌                  | 22/674 [00:10<02:30,  4.32it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • ZPL-2.0/ZPL-20-32.txt → Score: 0.0000
#   • ZPL-2.0/ZPL-2.0-38.txt → Score: 0.0000
#   • ZPL-2.1/ZPL-2.1-25.txt → Score: 0.0000
#   • ZPL-2.1/ZPL-21-32.txt → Score: 0.0000
#   • Intel/Intel-22.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.164 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 25 hit → 479 candidates
#  - LSH returned 479 candidates in 0.040 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 479 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 479/479 [00:00<00:00, 163485.36it/s]
# 🔍 Evaluating Queries:   4%|▋                  | 24/674 [00:10<02:11,  4.94it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GPL-3.0-only/GPL-3.0-only-87.txt → Score: 0.9286
#   • GPL-3.0-only/GPL-3.0-only-317.txt → Score: 0.9286
#   • GPL-3.0-only/GPL-3.0-only-262.txt → Score: 0.9286
#   • GPL-3.0-only/GPL-3.0-only-375.txt → Score: 0.9286
#   • GPL-3.0-only/GPL-3.0-only-216.txt → Score: 0.9286
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.045 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   4%|▋                  | 26/674 [00:10<01:53,  5.72it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.161 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.056 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 27 hit → 1 candidates
#  - LSH returned 1 candidates in 0.024 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 11214.72it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • NCGL-UK-2.0/NCGL-UK-20-13.txt → Score: 0.9983
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 4 hit → 1 candidates
#  - LSH returned 1 candidates in 0.152 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 14463.12it/s]
# 🔍 Evaluating Queries:   4%|▊                  | 29/674 [00:10<01:29,  7.19it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • NCGL-UK-2.0/NCGL-UK-2.0-37.txt → Score: 1.0679
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 5 candidates
# [DEBUG] Table 1 hit → 5 candidates
# [DEBUG] Table 2 hit → 5 candidates
# [DEBUG] Table 3 hit → 5 candidates
# [DEBUG] Table 4 hit → 5 candidates
# [DEBUG] Table 5 hit → 5 candidates
# [DEBUG] Table 6 hit → 5 candidates
# [DEBUG] Table 7 hit → 5 candidates
# [DEBUG] Table 8 hit → 5 candidates
# [DEBUG] Table 9 hit → 5 candidates
# [DEBUG] Table 10 hit → 5 candidates
# [DEBUG] Table 11 hit → 5 candidates
# [DEBUG] Table 12 hit → 5 candidates
# [DEBUG] Table 13 hit → 5 candidates
# [DEBUG] Table 14 hit → 5 candidates
# [DEBUG] Table 15 hit → 5 candidates
# [DEBUG] Table 16 hit → 5 candidates
# [DEBUG] Table 17 hit → 5 candidates
# [DEBUG] Table 18 hit → 5 candidates
# [DEBUG] Table 19 hit → 5 candidates
# [DEBUG] Table 20 hit → 5 candidates
# [DEBUG] Table 21 hit → 5 candidates
# [DEBUG] Table 22 hit → 5 candidates
# [DEBUG] Table 23 hit → 5 candidates
# [DEBUG] Table 24 hit → 5 candidates
# [DEBUG] Table 25 hit → 5 candidates
# [DEBUG] Table 26 hit → 5 candidates
# [DEBUG] Table 27 hit → 5 candidates
# [DEBUG] Table 28 hit → 5 candidates
# [DEBUG] Table 29 hit → 5 candidates
#  - LSH returned 5 candidates in 0.022 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 5 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 5/5 [00:00<00:00, 55043.36it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-109.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-78.txt → Score: 0.0000
#   • ZoneAlarm-EULA/ZoneAlarm-EULA-510.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-83.txt → Score: 0.0000
#   • LiLiQ-P-1.1/LiLiQ-P-1.1-87.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 22 hit → 1 candidates
#  - LSH returned 1 candidates in 0.028 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 17331.83it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-386.txt → Score: 1.0672
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 28 hit → 2 candidates
#  - LSH returned 2 candidates in 0.036 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 2 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 2/2 [00:00<00:00, 26715.31it/s]
# 🔍 Evaluating Queries:   5%|▉                  | 33/674 [00:10<00:59, 10.76it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-245.txt → Score: 0.6086
#   • CC-BY-3.0/CC-BY-3.0-157_Split_SPDX_Licenses.txt → Score: 0.6086
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.019 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.020 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 3 hit → 2 candidates
# [DEBUG] Table 4 hit → 2 candidates
# [DEBUG] Table 7 hit → 2 candidates
# [DEBUG] Table 8 hit → 3 candidates
# [DEBUG] Table 12 hit → 1 candidates
# [DEBUG] Table 15 hit → 2 candidates
# [DEBUG] Table 17 hit → 1 candidates
# [DEBUG] Table 18 hit → 1 candidates
# [DEBUG] Table 28 hit → 3 candidates
# [DEBUG] Table 29 hit → 1 candidates
#  - LSH returned 5 candidates in 0.153 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 5 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 5/5 [00:00<00:00, 27165.18it/s]
# 🔍 Evaluating Queries:   5%|▉                  | 35/674 [00:11<00:58, 10.89it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • MITNFA/MITNFA-6.txt → Score: 0.1160
#   • Imlib2/Imlib2-20.txt → Score: 0.1925
#   • MITNFA/MITNFA-6_Split_SPDX_Licenses.txt → Score: 0.2866
#   • ZPL-2.1/ZPL-2.1-32.txt → Score: 0.4597
#   • Intel/Intel-26.txt → Score: 0.5110
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   5%|█                  | 37/674 [00:11<01:11,  8.93it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.305 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.041 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.054 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 478 candidates
# [DEBUG] Table 20 hit → 479 candidates
#  - LSH returned 479 candidates in 0.029 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 479 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 479/479 [00:00<00:00, 194113.20it/s]
# 🔍 Evaluating Queries:   6%|█                  | 39/674 [00:11<01:02, 10.12it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GPL-3.0-only/GPL-3.0-only-87.txt → Score: 0.3580
#   • GPL-3.0-only/GPL-3.0-only-317.txt → Score: 0.3580
#   • GPL-3.0-only/GPL-3.0-only-262.txt → Score: 0.3580
#   • GPL-3.0-only/GPL-3.0-only-375.txt → Score: 0.3580
#   • GPL-3.0-only/GPL-3.0-only-216.txt → Score: 0.3580
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   6%|█▏                 | 43/674 [00:11<00:47, 13.42it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.047 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.018 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.032 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.070 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.036 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.022 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   7%|█▎                 | 46/674 [00:11<00:51, 12.21it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.236 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.696 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   7%|█▎                 | 48/674 [00:13<03:00,  3.47it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.261 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   7%|█▍                 | 50/674 [00:14<02:37,  3.95it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.252 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.038 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   8%|█▌                 | 54/674 [00:14<01:43,  5.97it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.244 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.023 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.018 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.068 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 5 candidates
# [DEBUG] Table 1 hit → 3 candidates
# [DEBUG] Table 2 hit → 3 candidates
# [DEBUG] Table 3 hit → 3 candidates
# [DEBUG] Table 4 hit → 3 candidates
# [DEBUG] Table 5 hit → 2 candidates
# [DEBUG] Table 6 hit → 4 candidates
# [DEBUG] Table 7 hit → 3 candidates
# [DEBUG] Table 8 hit → 3 candidates
# [DEBUG] Table 9 hit → 2 candidates
# [DEBUG] Table 10 hit → 1 candidates
# [DEBUG] Table 11 hit → 3 candidates
# [DEBUG] Table 12 hit → 3 candidates
# [DEBUG] Table 13 hit → 1 candidates
# [DEBUG] Table 14 hit → 5 candidates
# [DEBUG] Table 15 hit → 3 candidates
# [DEBUG] Table 16 hit → 1 candidates
# [DEBUG] Table 17 hit → 2 candidates
# [DEBUG] Table 18 hit → 4 candidates
# [DEBUG] Table 19 hit → 3 candidates
# [DEBUG] Table 20 hit → 3 candidates
# [DEBUG] Table 21 hit → 1 candidates
# [DEBUG] Table 22 hit → 5 candidates
# [DEBUG] Table 23 hit → 4 candidates
# [DEBUG] Table 24 hit → 2 candidates
# [DEBUG] Table 25 hit → 2 candidates
# [DEBUG] Table 26 hit → 3 candidates
# [DEBUG] Table 27 hit → 1 candidates
# [DEBUG] Table 28 hit → 3 candidates
# [DEBUG] Table 29 hit → 3 candidates
#  - LSH returned 6 candidates in 0.329 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 6 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 6/6 [00:00<00:00, 31575.69it/s]
# 🔍 Evaluating Queries:   8%|█▌                 | 56/674 [00:14<01:45,  5.85it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • gnu-javamail-exception/gnu-javamail-exception-2.txt → Score: 0.0000
#   • gnu-javamail-exception/gnu-javamail-exception-1_Split_SPDX_Licenses.txt → Score: 0.0405
#   • gnu-javamail-exception/gnu-javamail-exception-3.txt → Score: 0.0514
#   • gnu-javamail-exception/gnu-javamail-exception-2_Split_SPDX_Licenses.txt → Score: 0.2178
#   • gnu-javamail-exception/gnu-javamail-exception-1.txt → Score: 0.2178
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.025 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 153 candidates
# [DEBUG] Table 1 hit → 153 candidates
# [DEBUG] Table 2 hit → 153 candidates
# [DEBUG] Table 3 hit → 153 candidates
# [DEBUG] Table 4 hit → 153 candidates
# [DEBUG] Table 5 hit → 153 candidates
# [DEBUG] Table 6 hit → 153 candidates
# [DEBUG] Table 7 hit → 153 candidates
# [DEBUG] Table 8 hit → 153 candidates
# [DEBUG] Table 9 hit → 153 candidates
# [DEBUG] Table 10 hit → 153 candidates
# [DEBUG] Table 11 hit → 153 candidates
# [DEBUG] Table 12 hit → 153 candidates
# [DEBUG] Table 13 hit → 153 candidates
# [DEBUG] Table 14 hit → 153 candidates
# [DEBUG] Table 15 hit → 153 candidates
# [DEBUG] Table 16 hit → 153 candidates
# [DEBUG] Table 17 hit → 153 candidates
# [DEBUG] Table 18 hit → 153 candidates
# [DEBUG] Table 19 hit → 153 candidates
# [DEBUG] Table 20 hit → 153 candidates
# [DEBUG] Table 21 hit → 153 candidates
# [DEBUG] Table 22 hit → 153 candidates
# [DEBUG] Table 23 hit → 153 candidates
# [DEBUG] Table 24 hit → 153 candidates
# [DEBUG] Table 25 hit → 153 candidates
# [DEBUG] Table 26 hit → 153 candidates
# [DEBUG] Table 27 hit → 153 candidates
# [DEBUG] Table 28 hit → 153 candidates
# [DEBUG] Table 29 hit → 153 candidates
#  - LSH returned 153 candidates in 0.024 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 153 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 153/153 [00:00<00:00, 141818.46it/s]
# 🔍 Evaluating Queries:   9%|█▋                 | 60/674 [00:15<01:06,  9.18it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CPL-0.5/CPL-0.5-52.txt → Score: 0.0000
#   • CPL-0.5/CPL-0.5-151.txt → Score: 0.0000
#   • CPL-0.5/CPL-0.5-84.txt → Score: 0.0000
#   • CPL-0.5/CPL-0.5-156.txt → Score: 0.0000
#   • CPL-0.5/CPL-0.5-11.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.015 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.020 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.042 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.054 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   9%|█▋                 | 62/674 [00:15<00:59, 10.26it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.066 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.251 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:   9%|█▊                 | 64/674 [00:15<01:23,  7.31it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.253 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  10%|█▊                 | 66/674 [00:15<01:24,  7.21it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.253 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.035 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 17 hit → 1 candidates
# [DEBUG] Table 18 hit → 1 candidates
# [DEBUG] Table 26 hit → 1 candidates
#  - LSH returned 2 candidates in 0.252 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 2 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 2/2 [00:00<00:00, 26973.02it/s]
# 🔍 Evaluating Queries:  10%|█▉                 | 68/674 [00:16<01:26,  7.03it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GPL-3.0-with-bison-exception/GPL-3.0-with-bison-exception-4.txt → Score: 0.1537
#   • GPL-3.0-with-bison-exception/GPL-3.0-with-bison-exception-2.txt → Score: 0.3269
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.048 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.014 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 582 candidates
# [DEBUG] Table 1 hit → 582 candidates
# [DEBUG] Table 2 hit → 582 candidates
# [DEBUG] Table 3 hit → 582 candidates
# [DEBUG] Table 4 hit → 582 candidates
# [DEBUG] Table 5 hit → 582 candidates
# [DEBUG] Table 6 hit → 582 candidates
# [DEBUG] Table 7 hit → 582 candidates
# [DEBUG] Table 8 hit → 585 candidates
# [DEBUG] Table 9 hit → 585 candidates
# [DEBUG] Table 10 hit → 582 candidates
# [DEBUG] Table 11 hit → 582 candidates
# [DEBUG] Table 12 hit → 582 candidates
# [DEBUG] Table 13 hit → 582 candidates
# [DEBUG] Table 14 hit → 582 candidates
# [DEBUG] Table 15 hit → 582 candidates
# [DEBUG] Table 16 hit → 944 candidates
# [DEBUG] Table 17 hit → 582 candidates
# [DEBUG] Table 18 hit → 585 candidates
# [DEBUG] Table 19 hit → 582 candidates
# [DEBUG] Table 20 hit → 582 candidates
# [DEBUG] Table 21 hit → 585 candidates
# [DEBUG] Table 22 hit → 582 candidates
# [DEBUG] Table 23 hit → 582 candidates
# [DEBUG] Table 24 hit → 582 candidates
# [DEBUG] Table 25 hit → 585 candidates
# [DEBUG] Table 26 hit → 582 candidates
# [DEBUG] Table 27 hit → 582 candidates
# [DEBUG] Table 28 hit → 582 candidates
# [DEBUG] Table 29 hit → 582 candidates
#  - LSH returned 947 candidates in 0.024 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 947 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 947/947 [00:00<00:00, 217608.39it/s]
# 🔍 Evaluating Queries:  11%|██                 | 71/674 [00:16<01:02,  9.68it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • OSL-2.1/OSL-2.1-123_Split_SPDX_Licenses.txt → Score: 0.0000
#   • OSL-2.1/OSL-2.1-85_Split_DB_Foss_Licenses.txt → Score: 0.0000
#   • OSL-2.1/OSL-2.1-79_Split_DB_Foss_Licenses.txt → Score: 0.0000
#   • OSL-2.1/OSL-2.1-152_Split_SPDX_Licenses.txt → Score: 0.0000
#   • OSL-2.1/OSL-2.1-178.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.047 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 2 candidates
#  - LSH returned 2 candidates in 0.022 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 2 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 2/2 [00:00<00:00, 19972.88it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • ZPL-2.0/ZPL-2.0-24_Split_SPDX_Licenses.txt → Score: 1.0452
#   • SCEA/SCEA-130.txt → Score: 1.1600
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.029 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  11%|██                 | 74/674 [00:16<01:00,  9.84it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.240 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.024 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 1 candidates
# [DEBUG] Table 1 hit → 1 candidates
# [DEBUG] Table 2 hit → 1 candidates
# [DEBUG] Table 3 hit → 1 candidates
# [DEBUG] Table 4 hit → 1 candidates
# [DEBUG] Table 5 hit → 1 candidates
# [DEBUG] Table 6 hit → 1 candidates
# [DEBUG] Table 7 hit → 1 candidates
# [DEBUG] Table 8 hit → 1 candidates
# [DEBUG] Table 9 hit → 1 candidates
# [DEBUG] Table 10 hit → 1 candidates
# [DEBUG] Table 11 hit → 1 candidates
# [DEBUG] Table 12 hit → 1 candidates
# [DEBUG] Table 13 hit → 1 candidates
# [DEBUG] Table 14 hit → 1 candidates
# [DEBUG] Table 15 hit → 1 candidates
# [DEBUG] Table 16 hit → 1 candidates
# [DEBUG] Table 17 hit → 1 candidates
# [DEBUG] Table 18 hit → 1 candidates
# [DEBUG] Table 19 hit → 1 candidates
# [DEBUG] Table 20 hit → 1 candidates
# [DEBUG] Table 21 hit → 1 candidates
# [DEBUG] Table 22 hit → 1 candidates
# [DEBUG] Table 23 hit → 1 candidates
# [DEBUG] Table 24 hit → 1 candidates
# [DEBUG] Table 25 hit → 1 candidates
# [DEBUG] Table 26 hit → 1 candidates
# [DEBUG] Table 27 hit → 1 candidates
# [DEBUG] Table 28 hit → 1 candidates
# [DEBUG] Table 29 hit → 1 candidates
#  - LSH returned 1 candidates in 0.246 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 1/1 [00:00<00:00, 12826.62it/s]
# 🔍 Evaluating Queries:  11%|██▏                | 76/674 [00:16<01:05,  9.07it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CrystalStacker/CrystalStacker-18.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.255 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 2 candidates
#  - LSH returned 2 candidates in 0.099 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 2 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 2/2 [00:00<00:00, 25040.62it/s]
# 🔍 Evaluating Queries:  12%|██▏                | 78/674 [00:17<01:16,  7.81it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • GFDL-1.3/GFDL-1.3-453.txt → Score: 1.1819
#   • GFDL-1.2/GFDL-1.2-423.txt → Score: 1.1819
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  12%|██▏                | 79/674 [00:17<01:26,  6.86it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.240 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 17 hit → 1 candidates
# [DEBUG] Table 25 hit → 718 candidates
#  - LSH returned 719 candidates in 0.035 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 719 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 719/719 [00:00<00:00, 211346.60it/s]
# 🔍 Evaluating Queries:  12%|██▎                | 81/674 [00:17<01:10,  8.44it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-361_Split_SPDX_Licenses.txt → Score: 1.0033
#   • CC-BY-3.0/CC-BY-3.0-318.txt → Score: 1.0033
#   • CC-BY-3.0/CC-BY-3.0-225.txt → Score: 1.0033
#   • CC-BY-3.0/CC-BY-3.0-211_Split_SPDX_Licenses.txt → Score: 1.0033
#   • CC-BY-3.0/CC-BY-3.0-215_Split_SPDX_Licenses.txt → Score: 1.0033
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.029 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 28 hit → 1 candidates
# ...
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  96%|█████████████████▎| 646/674 [01:24<00:03,  7.03it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.076 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.095 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  96%|█████████████████▎| 648/674 [01:24<00:03,  7.73it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.092 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  96%|█████████████████▎| 650/674 [01:25<00:06,  3.94it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 1.119 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.044 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 5 candidates
#  - LSH returned 5 candidates in 0.790 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 5 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 5/5 [00:00<00:00, 15709.00it/s]
# 🔍 Evaluating Queries:  97%|█████████████████▍| 651/674 [01:26<00:07,  2.91it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • WashU/WashU-5.txt → Score: 0.8599
#   • WashU/WashU-3.txt → Score: 0.9465
#   • BSD-3-Clause-Clear/BSD-3-Clause-Clear-11.txt → Score: 0.9526
#   • PostgreSQL/PostgreSQL-2_Split_SPDX_Licenses.txt → Score: 1.1160
#   • PostgreSQL/PostgreSQL-1.txt → Score: 1.1160
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 4 candidates
# [DEBUG] Table 1 hit → 4 candidates
# [DEBUG] Table 2 hit → 5 candidates
# [DEBUG] Table 3 hit → 4 candidates
# [DEBUG] Table 4 hit → 4 candidates
# [DEBUG] Table 5 hit → 4 candidates
# [DEBUG] Table 6 hit → 4 candidates
# [DEBUG] Table 7 hit → 5 candidates
# [DEBUG] Table 8 hit → 4 candidates
# [DEBUG] Table 9 hit → 4 candidates
# [DEBUG] Table 10 hit → 4 candidates
# [DEBUG] Table 11 hit → 4 candidates
# [DEBUG] Table 12 hit → 4 candidates
# [DEBUG] Table 13 hit → 4 candidates
# [DEBUG] Table 14 hit → 4 candidates
# [DEBUG] Table 15 hit → 4 candidates
# [DEBUG] Table 16 hit → 4 candidates
# [DEBUG] Table 17 hit → 4 candidates
# [DEBUG] Table 18 hit → 4 candidates
# [DEBUG] Table 19 hit → 4 candidates
# [DEBUG] Table 20 hit → 4 candidates
# [DEBUG] Table 21 hit → 4 candidates
# [DEBUG] Table 22 hit → 4 candidates
# [DEBUG] Table 23 hit → 4 candidates
# [DEBUG] Table 24 hit → 6 candidates
# [DEBUG] Table 25 hit → 4 candidates
# [DEBUG] Table 26 hit → 4 candidates
# [DEBUG] Table 27 hit → 4 candidates
# [DEBUG] Table 28 hit → 4 candidates
# [DEBUG] Table 29 hit → 4 candidates
#  - LSH returned 8 candidates in 0.047 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 8 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████████| 8/8 [00:00<00:00, 20152.81it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • WashU/WashU-7.txt → Score: 0.0000
#   • WashU/WashU-1.txt → Score: 0.0000
#   • WashU/WashU-4.txt → Score: 0.0000
#   • WashU/WashU-6.txt → Score: 0.0000
#   • WashU/WashU-2.txt → Score: 0.3740
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 14 candidates
# [DEBUG] Table 3 hit → 2 candidates
# [DEBUG] Table 4 hit → 2 candidates
# [DEBUG] Table 5 hit → 6 candidates
# [DEBUG] Table 7 hit → 4 candidates
# [DEBUG] Table 8 hit → 46 candidates
# [DEBUG] Table 9 hit → 10 candidates
# [DEBUG] Table 10 hit → 6 candidates
# [DEBUG] Table 12 hit → 6 candidates
# [DEBUG] Table 15 hit → 2 candidates
# [DEBUG] Table 17 hit → 8 candidates
# [DEBUG] Table 19 hit → 12 candidates
# [DEBUG] Table 20 hit → 2 candidates
# [DEBUG] Table 21 hit → 6 candidates
# [DEBUG] Table 22 hit → 6 candidates
# [DEBUG] Table 24 hit → 8 candidates
# [DEBUG] Table 25 hit → 6 candidates
# [DEBUG] Table 26 hit → 2 candidates
# [DEBUG] Table 28 hit → 6 candidates
#  - LSH returned 70 candidates in 0.114 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 70 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|███████████████████████████████| 70/70 [00:00<00:00, 99156.12it/s]
# 🔍 Evaluating Queries:  97%|█████████████████▍| 653/674 [01:26<00:05,  3.82it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • OLDAP-2.6/OLDAP-2.6-2.txt → Score: 0.1327
#   • OLDAP-2.6/OLDAP-2.6-4_Split_SPDX_Licenses.txt → Score: 0.1327
#   • OLDAP-2.6/OLDAP-2.6-21.txt → Score: 0.1463
#   • OLDAP-2.6/OLDAP-2.6-9_Split_SPDX_Licenses.txt → Score: 0.1463
#   • OLDAP-2.8/OLDAP-2.8-7_Split_SPDX_Licenses.txt → Score: 0.1890
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 9 hit → 1 candidates
# [DEBUG] Table 27 hit → 718 candidates
# [DEBUG] Table 28 hit → 718 candidates
#  - LSH returned 719 candidates in 0.085 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 719 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████| 719/719 [00:00<00:00, 84860.98it/s]
# 🔍 Evaluating Queries:  97%|█████████████████▍| 654/674 [01:26<00:05,  3.98it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-361_Split_SPDX_Licenses.txt → Score: 0.3430
#   • CC-BY-3.0/CC-BY-3.0-318.txt → Score: 0.3430
#   • CC-BY-3.0/CC-BY-3.0-225.txt → Score: 0.3430
#   • CC-BY-3.0/CC-BY-3.0-211_Split_SPDX_Licenses.txt → Score: 0.3430
#   • CC-BY-3.0/CC-BY-3.0-215_Split_SPDX_Licenses.txt → Score: 0.3430
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 0 hit → 111 candidates
# [DEBUG] Table 1 hit → 111 candidates
# [DEBUG] Table 2 hit → 111 candidates
# [DEBUG] Table 3 hit → 111 candidates
# [DEBUG] Table 4 hit → 111 candidates
# [DEBUG] Table 5 hit → 111 candidates
# [DEBUG] Table 6 hit → 111 candidates
# [DEBUG] Table 7 hit → 111 candidates
# [DEBUG] Table 8 hit → 111 candidates
# [DEBUG] Table 9 hit → 111 candidates
# [DEBUG] Table 10 hit → 112 candidates
# [DEBUG] Table 11 hit → 112 candidates
# [DEBUG] Table 12 hit → 111 candidates
# [DEBUG] Table 13 hit → 111 candidates
# [DEBUG] Table 14 hit → 111 candidates
# [DEBUG] Table 15 hit → 111 candidates
# [DEBUG] Table 16 hit → 111 candidates
# [DEBUG] Table 17 hit → 111 candidates
# [DEBUG] Table 18 hit → 111 candidates
# [DEBUG] Table 19 hit → 111 candidates
# [DEBUG] Table 20 hit → 111 candidates
# [DEBUG] Table 21 hit → 111 candidates
# [DEBUG] Table 22 hit → 111 candidates
# [DEBUG] Table 23 hit → 111 candidates
# [DEBUG] Table 24 hit → 111 candidates
# [DEBUG] Table 25 hit → 111 candidates
# [DEBUG] Table 26 hit → 111 candidates
# [DEBUG] Table 27 hit → 111 candidates
# [DEBUG] Table 28 hit → 111 candidates
# [DEBUG] Table 29 hit → 111 candidates
#  - LSH returned 112 candidates in 0.084 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 112 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|█████████████████████████████| 112/112 [00:00<00:00, 53491.47it/s]
# 🔍 Evaluating Queries:  97%|█████████████████▍| 655/674 [01:27<00:04,  4.46it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • RealNetworks-EULA/RealNetworks-EULA-41.txt → Score: 0.0000
#   • RealNetworks-EULA/RealNetworks-EULA-5.txt → Score: 0.0000
#   • RealNetworks-EULA/RealNetworks-EULA-57.txt → Score: 0.0000
#   • RealNetworks-EULA/RealNetworks-EULA-84.txt → Score: 0.0000
#   • RealNetworks-EULA/RealNetworks-EULA-46.txt → Score: 0.0000
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.088 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  97%|█████████████████▌| 657/674 [01:27<00:03,  5.59it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.119 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.073 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 8 hit → 1 candidates
#  - LSH returned 1 candidates in 0.700 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 1 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|██████████████████████████████████| 1/1 [00:00<00:00, 4609.13it/s]
# 🔍 Evaluating Queries:  98%|█████████████████▋| 661/674 [01:28<00:02,  5.38it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • OLDAP-2.6/OLDAP-2.6-33.txt → Score: 0.6393
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.045 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.059 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.057 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 19 hit → 718 candidates
#  - LSH returned 718 candidates in 0.067 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 718 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 718/718 [00:00<00:00, 192023.86it/s]
# 🔍 Evaluating Queries:  98%|█████████████████▋| 663/674 [01:28<00:01,  6.51it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-361_Split_SPDX_Licenses.txt → Score: 0.5772
#   • CC-BY-3.0/CC-BY-3.0-318.txt → Score: 0.5772
#   • CC-BY-3.0/CC-BY-3.0-225.txt → Score: 0.5772
#   • CC-BY-3.0/CC-BY-3.0-211_Split_SPDX_Licenses.txt → Score: 0.5772
#   • CC-BY-3.0/CC-BY-3.0-215_Split_SPDX_Licenses.txt → Score: 0.5772
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  99%|█████████████████▊| 665/674 [01:28<00:01,  5.35it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.454 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.064 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.025 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 24 hit → 718 candidates
# [DEBUG] Table 28 hit → 2 candidates
#  - LSH returned 720 candidates in 0.044 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 720 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|████████████████████████████| 720/720 [00:00<00:00, 210901.52it/s]
# 🔍 Evaluating Queries:  99%|█████████████████▊| 667/674 [01:28<00:01,  6.81it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • CC-BY-3.0/CC-BY-3.0-361_Split_SPDX_Licenses.txt → Score: 0.5685
#   • CC-BY-3.0/CC-BY-3.0-318.txt → Score: 0.5685
#   • CC-BY-3.0/CC-BY-3.0-225.txt → Score: 0.5685
#   • CC-BY-3.0/CC-BY-3.0-211_Split_SPDX_Licenses.txt → Score: 0.5685
#   • CC-BY-3.0/CC-BY-3.0-215_Split_SPDX_Licenses.txt → Score: 0.5685
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries:  99%|█████████████████▉| 670/674 [01:29<00:00,  9.47it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.055 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.044 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.030 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
# 🔍 Evaluating Queries: 100%|█████████████████▉| 672/674 [01:29<00:00,  7.05it/s]
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.431 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.042 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
#  - LSH returned 0 candidates in 0.056 sec
#  No candidates found. Possibly due to hash size or vector sparsity.
#
#  [STEP 1] Embedding query text...
#   - Query vector shape: (384,)
#   - Non-zero embedding dimensions: 384
#
#  [STEP 2] Querying LSH index...
# [DEBUG] Table 1 hit → 2 candidates
# [DEBUG] Table 5 hit → 42 candidates
# [DEBUG] Table 9 hit → 42 candidates
# [DEBUG] Table 13 hit → 40 candidates
# [DEBUG] Table 14 hit → 2 candidates
# [DEBUG] Table 18 hit → 6 candidates
# [DEBUG] Table 20 hit → 42 candidates
# [DEBUG] Table 25 hit → 84 candidates
# [DEBUG] Table 26 hit → 86 candidates
#  - LSH returned 96 candidates in 0.030 sec
#
#  [STEP 3] Matching candidate filenames to vectors...
#   - Found 96 vectors for comparison.
#
#  [STEP 4] Computing distances...
# Scoring: 100%|██████████████████████████████| 96/96 [00:00<00:00, 202135.13it/s]
# 🔍 Evaluating Queries: 100%|██████████████████| 674/674 [01:29<00:00,  7.52it/s]
#  [STEP 5] Selecting top matches...
#
#  Top-5 nearest results:
#   • OLDAP-2.6/OLDAP-2.6-27_Split_SPDX_Licenses.txt → Score: 0.2350
#   • OLDAP-2.6/OLDAP-2.6-6.txt → Score: 0.2350
#   • OLDAP-2.6/OLDAP-2.6-27.txt → Score: 0.2382
#   • OLDAP-2.6/OLDAP-2.6-3_Split_SPDX_Licenses.txt → Score: 0.2382
#   • OLDAP-2.6/OLDAP-2.6-25.txt → Score: 0.2382
#
# ✅ Overall accuracy: 36.94% (249/674)

# %%
df_eval
# Out:
#      query_index                                       text_preview  \
# 0              0  INTERBASE PUBLIC LICENSE Version 1.0 1 Definit...
# 1              1  3DFX GLIDE Source Code General Public License ...
# 2              2  As a special exception, if you create a docume...
# 3              3  Lucent disclaims all warranties with regard to...
# 4              4  \xe3\x82\xa2\xe3\x83\x88\xe3\x83\xaa\xe3\x83\x...
# ..           ...                                                ...
# 669          669  Common Documentation License Version 1.0 - Feb...
# 670          670  Sybase Open Watcom Public License version 1.0 ...
# 671          671  Open CASCADE Technology Public License License...
# 672          672                              8. Indemnification...
# 673          673  The OpenLDAP Public License Version 2.5, 11 Ma...
#
#      true_label                                      matched_files  correct  \
# 0             1                                                 []    False
# 1             1  [CC-BY-3.0/CC-BY-3.0-371.txt, SCEA/SCEA-41_Spl...     True
# 2             1  [gnu-javamail-exception/gnu-javamail-exception...     True
# 3             1                                                 []    False
# 4             1                                                 []    False
# ..          ...                                                ...      ...
# 669           1                                                 []    False
# 670           1                                                 []    False
# 671           1                                                 []    False
# 672           1                                                 []    False
# 673           1  [OLDAP-2.6/OLDAP-2.6-27_Split_SPDX_Licenses.tx...     True
#
#          license_folder
# 0             Interbase
# 1                 Glide
# 2    Font-exception-2.0
# 3         StandardML-NJ
# 4       CC-BY-SA-2.1-JP
# ..                  ...
# 669             CDL-1.0
# 670          Watcom-1.0
# 671                OCCT
# 672          Wintertree
# 673           OLDAP-2.5
#
# [674 rows x 6 columns]

# %%
# Filter only license-labeled samples
license_results = df_eval[df_eval['true_label'] == 1]

# Check which license folders were correctly identified
correctly_detected = license_results[license_results['correct'] == True]['license_folder'].unique()

# Cross-check against your list
correct_licenses = sorted(set(correctly_detected).intersection(set(unique_licenses)))
missing_licenses = sorted(set(unique_licenses) - set(correctly_detected))

print(f"\n Detected {len(correct_licenses)}/{len(unique_licenses)} target licenses correctly.\n")
print(" Correctly Detected Licenses:")
print("\n".join(correct_licenses))

print("\n Missing Licenses (not detected correctly):")
print("\n".join(missing_licenses))
# Out:
#  Detected 46/46 target licenses correctly.
#
# 🎯 Correctly Detected Licenses:
# AAL
# BSD-3-Clause-Clear
# CATOSL
# CC-BY-3.0
# CC-BY-SA-3.0-AT
# CPL-0.5
# CrystalStacker
# FTL
# Ferris-1.2
# GFDL-1.1-no-invariants-or-later
# GFDL-1.2
# GFDL-1.2-invariants-or-later
# GFDL-1.2-only
# GFDL-1.3
# GFDL-1.3-invariants-or-later
# GPL-3.0-only
# GPL-3.0-with-bison-exception
# Imlib2
# Intel
# LiLiQ-P-1.1
# MITNFA
# MX4J
# NCGL-UK-2.0
# NLOD-1.0
# OASIS
# OLDAP-2.1
# OLDAP-2.6
# OLDAP-2.8
# OSL-2.1
# OpenMarket
# Parity-7.0.0
# PostgreSQL
# RealNetworks-EULA
# SCEA
# VIM
# W3C
# WashU
# YPL-1.0
# YPL-1.1
# ZPL-2.0
# ZPL-2.1
# Zed
# ZoneAlarm-EULA
# gnu-javamail-exception
# info-zip
# libtiff
#
#  Missing Licenses (not detected correctly):

# %%
non_license_results = df_eval[df_eval['true_label'] == 0]

correct_nonlicenses = non_license_results[non_license_results['correct'] == True]
incorrect_nonlicenses = non_license_results[non_license_results['correct'] == False]

print(f"\n Correctly identified {len(correct_nonlicenses)}/{len(non_license_results)} non-license texts.\n")

print(" Incorrectly identified these non-license texts as licenses:")
for i, row in incorrect_nonlicenses.iterrows():
    print(f" - Preview: {row['text_preview']}")
    print(f"   Matched files: {row['matched_files']}\n")
# Out:
#  Correctly identified 20/20 non-license texts.
#
#  Incorrectly identified these non-license texts as licenses:

# %% [markdown]
# # Points to note:
# - Identified all the licenses that were indexed correctly. (46 licenses in 10000 file samples)
# - They were (46/654) licenses that were indexed into LSH.
# - Identified all the non license text correclty. (20/674) samples.
# - 608 licenses were not indexed, that is they were not part of the search space. Even then, it identified some statements that it had not seen previously. (203/608)
# - Overall accuracy even with only (10000/162833) files indexed.

# %%
df_eval.to_csv("license_detection_results.csv", index=False)
