# %%
import os
import shutil
import pandas as pd
from pathlib import Path

# === SETUP ROOT PATH ===
project_root = Path("..").resolve()
csv_path = project_root / "license_data_summary.csv"
source_dirs = [project_root / "Split-DB-Foss-Licenses", project_root / "Split-SPDX-Licenses"]
output_base = project_root / "Combined-Licenses"

# === READ CSV AND GET UNIQUE LICENSES ===
df = pd.read_csv(csv_path)
unique_licenses = df['license'].dropna().unique()

# === CREATE OUTPUT STRUCTURE ===
output_base.mkdir(parents=True, exist_ok=True)

# === COPY FILES FROM BOTH SOURCES TO THE COMBINED FOLDER ===
for license_name in unique_licenses:
    combined_license_dir = output_base / license_name
    combined_license_dir.mkdir(parents=True, exist_ok=True)

    for source in source_dirs:
        license_source_dir = source / license_name
        if license_source_dir.is_dir():
            for filename in os.listdir(license_source_dir):
                src_file = license_source_dir / filename
                if src_file.is_file():
                    dest_file = combined_license_dir / filename
                    if dest_file.exists():
                        base, ext = os.path.splitext(filename)
                        # Add source name to resolve conflicts
                        source_tag = source.name.replace('-', '_')
                        dest_file = combined_license_dir / f"{base}_{source_tag}{ext}"
                    shutil.copy2(src_file, dest_file)

print(f"✅ All licenses combined into: {output_base}")
# Out:
# ✅ All licenses combined into: /Users/rajuljha/Documents/gsoc/atarashi_classifier/Combined-Licenses

# %%
import os
import pandas as pd
from pathlib import Path

combined_path = Path("..") / "Combined-Licenses"
license_file_counts = {}

for license_dir in combined_path.iterdir():
    if license_dir.is_dir():
        txt_files = list(license_dir.glob("*.txt"))
        license_file_counts[license_dir.name] = len(txt_files)

# Convert to DataFrame and sort
df_counts = pd.DataFrame([
    {"license_name": name, "file_count": count}
    for name, count in license_file_counts.items()
])

df_counts = df_counts.sort_values(by="file_count", ascending=False)
for _, row in df_counts.iterrows():
    print(f"{row['license_name']}: {row['file_count']} files")

total_files = df_counts['file_count'].sum()
print(f"\nTotal .txt license files: {total_files}")

output_csv_path = Path("..") / "combined_license_file_counts.csv"
df_counts.to_csv(output_csv_path, index=False)

print(f"\n Saved sorted license file counts to: {output_csv_path}")
# Out:
# APL-1.0: 1795 files
# BitTorrent-1.1: 1792 files
# BitTorrent-1.0: 1644 files
# RPL-1.1: 1558 files
# NPL-1.1: 1502 files
# RPL-1.5: 1410 files
# NPL-1.0: 1317 files
# MPL-1.1: 1294 files
# SPL-1.0: 1283 files
# CUA-OPL-1.0: 1280 files
# RSCPL: 1278 files
# RHeCos-1.1: 1254 files
# ODbL-1.0: 1245 files
# Interbase-1.0: 1226 files
# RPSL-1.0: 1194 files
# NOSL: 1181 files
# SugarCRM-1.1.3: 1168 files
# Hacktivismo: 1165 files
# Motosoto: 1147 files
# OPL-1.0: 1125 files
# GPL-3.0: 1071 files
# GPL-3.0+: 1055 files
# CC-BY-SA-3.0-AT: 1033 files
# AGPL-3.0: 1011 files
# Zimbra-1.2: 1010 files
# CPAL-1.0: 973 files
# LGPL-2.1: 956 files
# MPL-1.0: 950 files
# gSOAP-1.3b: 945 files
# SNIA: 940 files
# LGPL-2.1+: 935 files
# NASA-1.3: 924 files
# GFDL-1.3: 916 files
# CC-BY-NC-ND-3.0-IGO: 909 files
# CC-BY-NC-SA-4.0: 907 files
# FreeImage: 892 files
# LGPL-2.0+: 892 files
# CC-BY-SA-4.0: 891 files
# ODC-By-1.0: 879 files
# CC-BY-NC-SA-3.0: 873 files
# LGPL-2.0: 867 files
# CDDL-1.1: 857 files
# GFDL-1.2: 856 files
# Jabber-1.0: 854 files
# CC-BY-3.0-AT: 847 files
# CDDL-1.0: 846 files
# CC-BY-SA-3.0: 845 files
# APSL-2.0: 842 files
# CC-BY-4.0: 834 files
# CC-BY-NC-4.0: 833 files
# SSPL-1.0: 829 files
# APSL-1.0: 823 files
# CC-BY-NC-ND-4.0: 813 files
# CC-BY-ND-4.0: 809 files
# Watcom-1.0: 807 files
# ErlPL-1.1: 802 files
# CC-BY-NC-3.0: 799 files
# CC-BY-NC-SA-2.5: 795 files
# CC-BY-NC-SA-2.0: 787 files
# CC-BY-3.0: 780 files
# APSL-1.1: 778 files
# CC-BY-SA-2.5: 776 files
# APSL-1.2: 775 files
# CECILL-1.1: 767 files
# CC-BY-SA-2.0: 756 files
# Citrix: 754 files
# MPL-2.0-no-copyleft-exception: 734 files
# GFDL-1.1: 734 files
# CPOL-1.02: 726 files
# CC-BY-NC-ND-3.0: 718 files
# MPL-2.0: 712 files
# LPPL-1.3c: 712 files
# CC-BY-NC-2.5: 702 files
# LPPL-1.3a: 700 files
# RCSL: 699 files
# SGI-B-1.1: 697 files
# CC-BY-ND-3.0: 697 files
# Terracotta: 695 files
# PDDL-1.0: 694 files
# CC-BY-NC-2.0: 694 files
# CC-BY-2.5: 694 files
# CC-BY-2.0: 690 files
# OSET-PL-2.1: 679 files
# SGI-B-1.0: 671 files
# CECILL-1.0: 669 files
# CC-BY-NC-ND-2.5: 660 files
# Interbase: 657 files
# CC-BY-NC-ND-2.0: 644 files
# CC-BY-ND-2.5: 643 files
# OSL-2.1: 639 files
# CC-BY-NC-SA-1.0: 639 files
# CC-BY-ND-2.0: 637 files
# Nokia: 625 files
# CC-BY-SA-1.0: 622 files
# CAL-1.0: 619 files
# GPL-2.0: 587 files
# D-FSL-1.0: 581 files
# SunJDK6: 579 files
# CC-BY-1.0: 571 files
# CC-BY-NC-1.0: 561 files
# GPL-2.0+: 560 files
# CC-BY-NC-ND-1.0: 557 files
# RedHat: 547 files
# CATOSL-1.1: 545 files
# Cygnus-eCos-1.0: 539 files
# LPL-1.02: 538 files
# AGPL-1.0: 529 files
# CC-BY-ND-1.0: 528 files
# ZoneAlarm-EULA: 510 files
# SISSL: 509 files
# LPL-1.0: 504 files
# OCLC-2.0: 493 files
# Skype-EULA: 490 files
# IPL-1.0: 488 files
# VMWare-EULA: 487 files
# GPL-3.0-or-later: 483 files
# GPL-3.0-only: 483 files
# TrueCrypt-3.0: 479 files
# GFDL-1.2-invariants+: 466 files
# SNIA-1.1: 459 files
# CECILL-C: 449 files
# Unicode-TOU: 446 files
# LGPLLR: 445 files
# AGPL-3.0-only: 442 files
# AGPL-3.0-or-later: 442 files
# Hauppauge: 433 files
# CECILL-B: 430 files
# LGPL-2.1-or-later: 428 files
# LGPL-2.1-only: 428 files
# SISSL-1.2: 427 files
# NPOSL-3.0: 424 files
# Ferris-1.2: 419 files
# LPPL-1.1: 417 files
# CECILL-2.1: 413 files
# LPPL-1.2: 413 files
# GFDL-1.3-no-invariants-or-later: 412 files
# GFDL-1.3-only: 412 files
# GFDL-1.3-invariants-only: 412 files
# GFDL-1.3-no-invariants-only: 412 files
# GFDL-1.3-or-later: 412 files
# GFDL-1.3-invariants-or-later: 412 files
# OCCT-PL: 409 files
# EUPL-1.2: 406 files
# GFDL-1.1-invariants+: 403 files
# OCCT: 402 files
# CECILL-2.0: 399 files
# QT.Commercial: 399 files
# LGPL-2.0-only: 398 files
# LGPL-2.0-or-later: 398 files
# OSL-1.1: 398 files
# OSL-2.0: 398 files
# EUPL-1.1: 396 files
# CompuServe: 393 files
# GFDL-1.2-no-invariants-only: 390 files
# GFDL-1.2-no-invariants-or-later: 390 files
# GFDL-1.2-invariants-or-later: 390 files
# GFDL-1.2-only: 390 files
# GFDL-1.2-or-later: 390 files
# GFDL-1.2-invariants-only: 390 files
# Spikesource: 383 files
# Ascender-EULA: 382 files
# LPPL-1.3b: 381 files
# CERN-OHL-1.2: 377 files
# UCL-1.0: 374 files
# OSL-3.0: 374 files
# OSL-1.0: 373 files
# AFL-3.0: 373 files
# EUPL-1.0: 372 files
# EPL-2.0: 368 files
# AFL-2.1: 363 files
# AFL-2.0: 363 files
# LPPL-1.3: 360 files
# GPL-1.0: 359 files
# GPL-1.0+: 358 files
# CPL-1.0: 358 files
# CC-BY-3.0-US: 347 files
# Python-2.0: 345 files
# SHL-0.51: 345 files
# EPL-1.0: 342 files
# Aladdin: 332 files
# GFDL-1.1-no-invariants-only: 331 files
# GFDL-1.1-invariants-or-later: 331 files
# GFDL-1.1-only: 331 files
# GFDL-1.1-invariants-only: 331 files
# GFDL-1.1-or-later: 331 files
# GFDL-1.1-no-invariants-or-later: 331 files
# Glide: 326 files
# ImageMagick: 325 files
# Helix.RealNetworks-EULA: 322 files
# SHL-0.5: 316 files
# Intel-ACPI: 308 files
# TAPR-OHL-1.0: 304 files
# copyleft-next-0.3.0: 297 files
# copyleft-next-0.3.1: 288 files
# IPA: 286 files
# ECL-2.0: 278 files
# Net-SNMP: 276 files
# NLOD-1.0: 273 files
# Zimbra-1.3: 270 files
# YPL-1.0: 270 files
# Zimbra-1.4: 270 files
# SCEA: 268 files
# Adaptec: 268 files
# Oracle-Dev: 268 files
# LAL-1.3: 267 files
# Python-2.0.1: 267 files
# Python-2.1.3: 267 files
# YPL-1.1: 266 files
# Docbook: 266 files
# Mindterm: 262 files
# Apache-2.0: 262 files
# CAL-1.0-Combined-Work-Exception: 262 files
# GPL-2.0-or-later: 260 files
# GPL-2.0-only: 260 files
# CERN-OHL-1.1: 260 files
# Motorola: 259 files
# Python-3.1.1: 257 files
# Python-2.3.7: 257 files
# Python-2.7: 257 files
# Python-2.6.5: 257 files
# MPL-EULA-3.0: 257 files
# Python-2.4.4: 257 files
# Python-2.5: 257 files
# VIM: 253 files
# Python-2.2.3: 252 files
# Yahoo-EULA: 247 files
# AGPL-1.0-only: 242 files
# AGPL-1.0-or-later: 242 files
# MPL-EULA-2.0: 240 files
# FTL: 238 files
# LiLiQ-R-1.1: 233 files
# ATI-EULA: 229 files
# LAL-1.2: 226 files
# LiLiQ-Rplus-1.1: 225 files
# CDLA-Sharing-1.0: 225 files
# CC0-1.0: 224 files
# MulanPSL-2.0: 219 files
# MPL-EULA-1.1: 218 files
# Against-DRM: 216 files
# AMDPLPA: 215 files
# CERN-OHL-S-2.0: 213 files
# CERN-OHL-W-2.0: 211 files
# CDLA-Permissive-1.0: 209 files
# O-UDA-1.0: 208 files
# Condor-1.1: 207 files
# CDL-1.0: 206 files
# Tapjoy: 204 files
# Hippocratic-2.1: 204 files
# LPPL-1.0: 202 files
# Piriform: 202 files
# CPL-0.5: 201 files
# Epinions: 199 files
# OGDL-Taiwan-1.0: 197 files
# IJG: 193 files
# OpenSSL: 192 files
# Frameworx-1.0: 191 files
# OpenGroup: 187 files
# TORQUE-1.1: 186 files
# CC-BY-SA-2.0-UK: 181 files
# MulanPSL-1.0: 179 files
# Artistic-2.0: 175 files
# QPL-1.0: 171 files
# RedHat-EULA: 168 files
# LiLiQ-P-1.1: 168 files
# Unicode: 167 files
# OLDAP-1.4: 167 files
# GPL-1.0-or-later: 167 files
# GPL-1.0-only: 167 files
# Artistic-1.0-Perl: 162 files
# Bitstream: 161 files
# LGPL-3.0: 160 files
# OLDAP-1.3: 157 files
# FAL-1.3: 157 files
# eGenix: 156 files
# Nvidia-EULA: 156 files
# Agere: 155 files
# Broadcom-EULA: 155 files
# ClArtistic: 154 files
# Flora-1.1: 154 files
# Fedora: 154 files
# Flora: 154 files
# OpenDefinition: 152 files
# LGPL-3.0+: 151 files
# EPICS: 151 files
# OLDAP-1.2: 150 files
# OLDAP-1.1: 150 files
# AFL-1.2: 143 files
# Cisco: 142 files
# MetroLink-1.0: 141 files
# Open-PL-1.0: 141 files
# NGPL: 138 files
# NBPL-1.0: 137 files
# Libpng: 136 files
# Artistic-1.0-cl8: 136 files
# OGTSL: 134 files
# AFL-1.1: 132 files
# CNRI-Python-GPL-Compatible: 127 files
# Artistic-1.0: 127 files
# Arphic: 126 files
# Majordomo-1.1: 126 files
# Wintertree: 126 files
# DOC: 126 files
# Zend-2.0: 125 files
# CERN-OHL-P-2.0: 123 files
# SMPPL: 122 files
# BSD-Protection: 121 files
# CC-BY-SA-2.1-JP: 118 files
# OPL: 117 files
# Sendmail-8.23: 117 files
# Sendmail: 117 files
# iMatix: 115 files
# CNRI-Jython: 115 files
# Aptana-1.0: 113 files
# RealNetworks-EULA: 113 files
# Parity-7.0.0: 108 files
# PolyForm-Small-Business-1.0.0: 105 files
# Comtrol: 103 files
# DSL: 102 files
# CNRI-Python: 101 files
# PHP-3.01: 101 files
# PHP-3.0: 101 files
# W3C-19980720: 101 files
# MTLL: 97 files
# OpenMap: 96 files
# FedoraCLA: 96 files
# MS-PL: 93 files
# NRL: 93 files
# PolyForm-Noncommercial-1.0.0: 93 files
# DigiRule-FOSS-exception: 92 files
# UCWare-EULA: 92 files
# OLDAP-2.1: 90 files
# etalab-2.0: 90 files
# zlib-acknowledgement: 89 files
# ZPL-1.1: 88 files
# OGL-UK-2.0: 88 files
# Nunit: 88 files
# OLDAP-2.3: 85 files
# OLDAP-2.2.2: 85 files
# ZPL-2.0: 85 files
# MS-RL: 85 files
# OLDAP-2.2.1: 84 files
# OLDAP-2.2: 84 files
# info-zip: 84 files
# Apache-1.1: 83 files
# Condor-1.0: 83 files
# OGL-UK-3.0: 83 files
# EUDatagrid: 81 files
# VOSTROM: 81 files
# Pixware-EULA: 80 files
# OLDAP-2.5: 80 files
# OLDAP-2.4: 80 files
# PSF-2.0: 77 files
# Plexus: 76 files
# Sleepycat: 76 files
# NCGL-UK-2.0: 76 files
# C-UDA-1.0: 75 files
# SSH-OpenSSH: 75 files
# Bahyph: 75 files
# OGL-Canada-2.0: 74 files
# GPL-3.0-with-GCC-exception: 74 files
# GCC-exception-3.1: 74 files
# OFL-1.1: 72 files
# OFL-1.1-no-RFN: 71 files
# OGL-UK-1.0: 71 files
# PHP-2.02: 71 files
# Caldera: 71 files
# OASIS: 71 files
# MS-LPL: 68 files
# Entessa: 67 files
# OLDAP-2.6: 67 files
# Apache-1.0: 67 files
# ACE: 66 files
# Mibble: 66 files
# xinetd: 65 files
# ZPL-2.1: 65 files
# Multics: 65 files
# OLDAP-2.0.1: 65 files
# OLDAP-2.0: 65 files
# CLISP-exception-2.0: 64 files
# JasPer-2.0: 64 files
# SHL-2.1: 64 files
# OGC-1.0: 63 files
# OLDAP-2.8: 63 files
# OLDAP-2.7: 63 files
# DSDP: 61 files
# Qhull: 61 files
# VSL-1.0: 61 files
# JPNIC: 61 files
# HP: 58 files
# LGPL-3.0-only: 57 files
# LGPL-3.0-or-later: 57 files
# 389-exception: 56 files
# Parity-6.0.0: 56 files
# Eurosym: 56 files
# WXwindows: 55 files
# SimPL-2.0: 55 files
# GPL-2.0-with-autoconf-exception: 55 files
# Ruby: 55 files
# Unicode-DFS-2015: 55 files
# Naumen: 54 files
# xpp: 54 files
# OFL-1.0: 53 files
# GPL-3.0-with-autoconf-exception: 53 files
# Autoconf-exception-3.0: 51 files
# AMPAS: 51 files
# psutils: 51 files
# M+: 50 files
# SAX-PD: 50 files
# TCL: 49 files
# Noweb: 49 files
# SWL: 48 files
# Autoconf-exception-2.0: 47 files
# BlueOak-1.0.0: 47 files
# Intel: 46 files
# bzip2-1.0.6: 46 files
# CCLRC: 45 files
# Spencer-94: 45 files
# Nvidia: 45 files
# TMate: 43 files
# Logica-OSL-1.0: 42 files
# SHL-2.0: 42 files
# W3C: 42 files
# Cube: 42 files
# AAL: 41 files
# Unicode-DFS-2016: 41 files
# Saxpath: 41 files
# OML: 41 files
# BSD-3-Clause-LBNL: 41 files
# Alfresco-FLOSS: 40 files
# gnuplot: 39 files
# Fawkes-Runtime-exception: 39 files
# Barr: 39 files
# XFree86-1.1: 38 files
# Oracle-Berkeley-DB: 38 files
# BSD-4-Clause: 38 files
# BSD-4-Clause-UC: 38 files
# SGI-B-2.0: 38 files
# Zlib: 38 files
# MakeIndex: 38 files
# BSD-3-Clause-No-Nuclear-Warranty: 37 files
# libpng-2.0: 37 files
# BSD-3-Clause-No-Nuclear-License: 37 files
# Mup: 37 files
# eCos-2.0: 36 files
# mpich2: 36 files
# AML: 35 files
# RSA-MD: 35 files
# Imlib2: 35 files
# bzip2-1.0.5: 35 files
# Giftware: 35 files
# NetCDF: 34 files
# Rdisc: 34 files
# CrystalStacker: 34 files
# JISP: 33 files
# ANTLR-PD: 33 files
# Spencer-86: 33 files
# Qwt-exception-1.0: 33 files
# H2-1.0: 32 files
# BSD-3-Clause-Attribution: 32 files
# EFL-2.0: 32 files
# BSD-3-Clause: 32 files
# W3C-20150513: 32 files
# TOSL: 32 files
# BSD-2-Clause-NetBSD: 32 files
# WxWindows-exception-3.1: 32 files
# Unidex: 32 files
# Phorum-2.0: 29 files
# FaCE: 29 files
# MitreCVW: 29 files
# BSD-2-Clause-Patent: 28 files
# MIT-enna: 28 files
# MX4J-1.0: 28 files
# Borceux: 28 files
# Wsuipa: 27 files
# libselinux-1.0: 27 files
# freertos-exception-2.0: 27 files
# ADSL: 27 files
# NCSA: 26 files
# BSD-1-Clause: 26 files
# BUSL-1.1: 26 files
# ECL-1.0: 26 files
# GPL-2.0-with-classpath-exception: 26 files
# Universal-FOSS-exception-1.0: 26 files
# Xnet: 25 files
# Spencer-99: 24 files
# BSD-2-Clause-FreeBSD: 24 files
# NIST-PD: 24 files
# NIST-PD-fallback: 24 files
# Flora-1.0: 24 files
# TU-Berlin-1.0: 24 files
# GLWTPL: 24 files
# TU-Berlin-2.0: 23 files
# CC-PDDC: 22 files
# openvpn-openssl-exception: 22 files
# OpenJDK-assembly-exception-1.0: 22 files
# OFL-1.1-RFN: 22 files
# EFL-1.0: 22 files
# HSQLDB: 21 files
# BSD-2-Clause: 21 files
# Migemo: 21 files
# Nokia-Qt-exception-1.1: 21 files
# BSD-2-Clause-Views: 20 files
# Classpath-exception-2.0: 20 files
# Adobe-2006: 20 files
# Unlicense: 20 files
# WordNet-3.0: 20 files
# RSA-Cryptoki: 20 files
# Xerox: 20 files
# FreeBSD-DOC: 19 files
# Qt-LGPL-exception-1.1: 19 files
# Public-domain: 19 files
# XSkat: 19 files
# Afmparse: 19 files
# LIBGCJ: 18 files
# Leptonica: 18 files
# HPND-sell-variant: 18 files
# HPND: 18 files
# ANTLR-PD-fallback: 18 files
# OpenMarket: 18 files
# EDL-1.0: 17 files
# GPL-2.0-with-font-exception: 17 files
# Trolltech: 17 files
# GPL-3.0+-with-classpath-exception: 17 files
# X11: 17 files
# Adobe-Glyph: 17 files
# GPL-2.0+-with-classpath-exception: 17 files
# Intel-WLAN: 17 files
# NLPL: 16 files
# PostgreSQL: 16 files
# ICU: 16 files
# Newsletr: 16 files
# TCP-wrappers: 16 files
# BSD-3-Clause-No-Nuclear-License-2014: 16 files
# ISC: 16 files
# WTFPL: 16 files
# LGPL-3.0-linking-exception: 16 files
# BSD-Source-Code: 15 files
# BSD-3-Clause-Clear: 15 files
# JSON: 15 files
# NAIST-2003: 15 files
# Font-exception-2.0: 15 files
# i2p-gpl-java-exception: 15 files
# GPL-CC-1.0: 15 files
# Abstyles: 14 files
# GPL-2.0-with-bison-exception: 14 files
# Qt-GPL-exception-1.0: 14 files
# Dual-license: 14 files
# BSD-3-Clause-Open-MPI: 14 files
# SMLNJ: 14 files
# curl: 14 files
# blessing: 14 files
# BSD-3-Clause-Modification: 13 files
# NTP: 13 files
# OFL-1.0-RFN: 13 files
# OFL-1.0-no-RFN: 13 files
# NTP-0: 13 files
# FLTK-exception: 13 files
# GL2PS: 13 files
# psfrag: 13 files
# IBM-pibs: 13 files
# diffmark: 13 files
# BSL-1.0: 12 files
# MirOS: 12 files
# Vixie: 12 files
# APAFML: 12 files
# Linux-OpenIB: 12 files
# MIT-advertising: 12 files
# MITNFA: 12 files
# OCCT-exception-1.0: 12 files
# UPL-1.0: 12 files
# Beerware: 11 files
# u-boot-exception-2.0: 11 files
# GPL-2.0-with-GCC-exception: 11 files
# MIT-CMU: 11 files
# Qmail: 11 files
# MIT-0: 11 files
# HaskellReport: 11 files
# OCaml-LGPL-linking-exception: 11 files
# Latex2e: 10 files
# 0BSD: 10 files
# MIT-feh: 10 files
# Bison-exception-2.2: 10 files
# Crossword: 10 files
# BSD-Doc: 10 files
# WebM: 10 files
# NewBSD: 10 files
# mif-exception: 10 files
# libtiff: 9 files
# Bootloader-exception: 9 files
# Cryptogams: 9 files
# HTMLTIDY: 9 files
# eCos-exception-2.0: 8 files
# MIT: 8 files
# GPL-2.0+-with-bison-exception: 8 files
# Glulxe: 8 files
# CMake: 8 files
# Fair: 8 files
# GPL-3.0-linking-source-exception: 8 files
# GPL-3.0-with-bison-exception: 8 files
# LZMA-exception: 8 files
# StandardML-NJ: 8 files
# Linux-syscall-note: 8 files
# DRL-1.0: 8 files
# GPL-3.0+-with-bison-exception: 8 files
# Zed: 8 files
# WashU: 8 files
# GD: 7 files
# CMU: 7 files
# LLVM-exception: 6 files
# gnu-javamail-exception: 6 files
# GCC-exception-2.0: 6 files
# BSD-4-Clause-Shortened: 6 files
# Dotseqn: 6 files
# SSH-short: 6 files
# FSFAP: 6 files
# dvipdfm: 6 files
# LGPL-2.1+-KDE-exception: 6 files
# ClearSilver: 5 files
# MIT-open-group: 5 files
# MIT-Modern-Variant: 5 files
# Freeware: 5 files
# FSFULLR: 4 files
# BSD-3-Clause-No-Military-License: 4 files
# AdobeAFM: 4 files
# Swift-exception: 4 files
# GPL-3.0-linking-exception: 4 files
# PS-or-PDF-font-exception-20170817: 4 files
# See-file: 4 files
# FSFUL: 4 files
# MX4J: 3 files
# CATOSL: 3 files
# CDDL: 3 files
# PHP: 3 files
# BSD: 3 files
# LGPL: 3 files
# XFree86: 3 files
# BSD-3-Clause-Severability: 3 files
# OLDAP: 3 files
# CC-BY: 3 files
# ZPL: 3 files
# CECILL: 3 files
# EFL: 3 files
# GPL: 3 files
# CC-BY-SA: 3 files
# Libtool-exception: 2 files
# MIT-style: 1 files
# Void: 1 files
# No_license_found: 1 files
# MPL-1.1-style: 1 files
# BSD-style: 1 files
# FSF: 1 files
# Open-PL-0.4: 1 files
# OPL-style: 1 files
# UnclassifiedLicense: 1 files
#
# Total .txt license files: 162833
#
#  Saved sorted license file counts to: ../combined_license_file_counts.csv
